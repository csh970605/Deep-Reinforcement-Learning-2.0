# %% [markdown]
# # Twin-Delayed DDPG

# %% [markdown]
# ## Installing the packages

# %%
# !pip install pybullet
# !pip install gym==0.22.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pybullet
#   Downloading pybullet-3.2.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (91.7 MB)
#      |████████████████████████████████| 91.7 MB 2.8 MB/s
# Installing collected packages: pybullet
# Successfully installed pybullet-3.2.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gym==0.22.0
#   Downloading gym-0.22.0.tar.gz (631 kB)
#      |████████████████████████████████| 631 kB 33.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.22.0) (1.5.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.8/dist-packages (from gym==0.22.0) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.22.0) (5.1.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.22.0) (1.21.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.10.0->gym==0.22.0) (3.11.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (PEP 517) ... done
#   Created wheel for gym: filename=gym-0.22.0-py3-none-any.whl size=708395 sha256=2eaedb8a0d1ab32192a6895630ed0c97a3f87ddd3c1236ff07335e1a45fbab0b
#   Stored in directory: /root/.cache/pip/wheels/4d/6e/7d/0e050cb65b427dd0db5c5ab2c9a1f1ffa3d58db2f4db516268
# Successfully built gym
# Installing collected packages: gym
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# Successfully installed gym-0.22.0

# %% [markdown]
# ## Importing the libraries

# %%
import os
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import pybullet_envs
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
from gym import wrappers
from torch.autograd import Variable
from collections import deque

# %% [markdown]
# ## Step 1: We initialize the Experience Replay memory

# %%
class ReplayBuffer(object):

  def __init__(self, max_size=1e6):
    self.storage = []
    self.max_size = max_size
    self.ptr = 0

  def add(self, transition):
    if len(self.storage) == self.max_size:
      self.storage[int(self.ptr)] = transition
      self.ptr = (self.ptr + 1) % self.max_size
    else:
      self.storage.append(transition)

  def sample(self, batch_size):
    ind = np.random.randint(0, len(self.storage), size=batch_size)
    batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = [], [], [], [], []
    for i in ind: 
      state, next_state, action, reward, done = self.storage[i]
      batch_states.append(np.array(state, copy=False))
      batch_next_states.append(np.array(next_state, copy=False))
      batch_actions.append(np.array(action, copy=False))
      batch_rewards.append(np.array(reward, copy=False))
      batch_dones.append(np.array(done, copy=False))
    return np.array(batch_states), np.array(batch_next_states), np.array(batch_actions), np.array(batch_rewards).reshape(-1, 1), np.array(batch_dones).reshape(-1, 1)

# %% [markdown]
# ## Step 2: We build one neural network for the Actor model and one neural network for the Actor target

# %%
class Actor(nn.Module):
  
  def __init__(self, state_dim, action_dim, max_action):
    super(Actor, self).__init__()
    self.layer_1 = nn.Linear(state_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, action_dim)
    self.max_action = max_action

  def forward(self, x):
    x = F.relu(self.layer_1(x))
    x = F.relu(self.layer_2(x))
    x = self.max_action * torch.tanh(self.layer_3(x))
    return x

# %% [markdown]
# ## Step 3: We build two neural networks for the two Critic models and two neural networks for the two Critic targets

# %%
class Critic(nn.Module):
  
  def __init__(self, state_dim, action_dim):
    super(Critic, self).__init__()
    # Defining the first Critic neural network
    self.layer_1 = nn.Linear(state_dim + action_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, 1)
    # Defining the second Critic neural network
    self.layer_4 = nn.Linear(state_dim + action_dim, 400)
    self.layer_5 = nn.Linear(400, 300)
    self.layer_6 = nn.Linear(300, 1)

  def forward(self, x, u):
    xu = torch.cat([x, u], 1)
    # Forward-Propagation on the first Critic Neural Network
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    # Forward-Propagation on the second Critic Neural Network
    x2 = F.relu(self.layer_4(xu))
    x2 = F.relu(self.layer_5(x2))
    x2 = self.layer_6(x2)
    return x1, x2

  def Q1(self, x, u):
    xu = torch.cat([x, u], 1)
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    return x1

# %% [markdown]
# ## Steps 4 to 15: Training Process

# %%
# Selecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Building the whole Training Process into a class

class TD3(object):
  
  def __init__(self, state_dim, action_dim, max_action):
    self.actor = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target.load_state_dict(self.actor.state_dict())
    self.actor_optimizer = torch.optim.Adam(self.actor.parameters())
    self.critic = Critic(state_dim, action_dim).to(device)
    self.critic_target = Critic(state_dim, action_dim).to(device)
    self.critic_target.load_state_dict(self.critic.state_dict())
    self.critic_optimizer = torch.optim.Adam(self.critic.parameters())
    self.max_action = max_action

  def select_action(self, state):
    state = torch.Tensor(state.reshape(1, -1)).to(device)
    return self.actor(state).cpu().data.numpy().flatten()

  def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
    
    for it in range(iterations):
      
      # Step 4: We sample a batch of transitions (s, s’, a, r) from the memory
      batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
      state = torch.Tensor(batch_states).to(device)
      next_state = torch.Tensor(batch_next_states).to(device)
      action = torch.Tensor(batch_actions).to(device)
      reward = torch.Tensor(batch_rewards).to(device)
      done = torch.Tensor(batch_dones).to(device)
      
      # Step 5: From the next state s’, the Actor target plays the next action a’
      next_action = self.actor_target(next_state)
      
      # Step 6: We add Gaussian noise to this next action a’ and we clamp it in a range of values supported by the environment
      noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
      noise = noise.clamp(-noise_clip, noise_clip)
      next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
      
      # Step 7: The two Critic targets take each the couple (s’, a’) as input and return two Q-values Qt1(s’,a’) and Qt2(s’,a’) as outputs
      target_Q1, target_Q2 = self.critic_target(next_state, next_action)
      
      # Step 8: We keep the minimum of these two Q-values: min(Qt1, Qt2)
      target_Q = torch.min(target_Q1, target_Q2)
      
      # Step 9: We get the final target of the two Critic models, which is: Qt = r + γ * min(Qt1, Qt2), where γ is the discount factor
      target_Q = reward + ((1 - done) * discount * target_Q).detach()
      
      # Step 10: The two Critic models take each the couple (s, a) as input and return two Q-values Q1(s,a) and Q2(s,a) as outputs
      current_Q1, current_Q2 = self.critic(state, action)
      
      # Step 11: We compute the loss coming from the two Critic models: Critic Loss = MSE_Loss(Q1(s,a), Qt) + MSE_Loss(Q2(s,a), Qt)
      critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
      
      # Step 12: We backpropagate this Critic loss and update the parameters of the two Critic models with a SGD optimizer
      self.critic_optimizer.zero_grad()
      critic_loss.backward()
      self.critic_optimizer.step()
      
      # Step 13: Once every two iterations, we update our Actor model by performing gradient ascent on the output of the first Critic model
      if it % policy_freq == 0:
        actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        # Step 14: Still once every two iterations, we update the weights of the Actor target by polyak averaging
        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
        
        # Step 15: Still once every two iterations, we update the weights of the Critic target by polyak averaging
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
  
  # Making a save method to save a trained model
  def save(self, filename, directory):
    torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, filename))
    torch.save(self.critic.state_dict(), '%s/%s_critic.pth' % (directory, filename))
  
  # Making a load method to load a pre-trained model
  def load(self, filename, directory):
    self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, filename)))
    self.critic.load_state_dict(torch.load('%s/%s_critic.pth' % (directory, filename)))

# %% [markdown]
# ## We make a function that evaluates the policy by calculating its average reward over 10 episodes

# %%
def evaluate_policy(policy, eval_episodes=10):
  avg_reward = 0.
  for _ in range(eval_episodes):
    obs = env.reset()
    done = False
    while not done:
      action = policy.select_action(np.array(obs))
      obs, reward, done, _ = env.step(action)
      avg_reward += reward
  avg_reward /= eval_episodes
  print ("---------------------------------------")
  print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
  print ("---------------------------------------")
  return avg_reward

# %% [markdown]
# ## We set the parameters

# %%
env_name = "Walker2DBulletEnv-v0" # Name of a environment (set it to any Continous environment you want)
seed = 0 # Random seed number
start_timesteps = 1e4 # Number of iterations/timesteps before which the model randomly chooses an action, and after which it starts to use the policy network
eval_freq = 5e3 # How often the evaluation step is performed (after how many timesteps)
max_timesteps = 5e5 # Total number of iterations/timesteps
save_models = True # Boolean checker whether or not to save the pre-trained model
expl_noise = 0.1 # Exploration noise - STD value of exploration Gaussian noise
batch_size = 100 # Size of the batch
discount = 0.99 # Discount factor gamma, used in the calculation of the total discounted reward
tau = 0.005 # Target network update rate
policy_noise = 0.2 # STD of Gaussian noise added to the actions for the exploration purposes
noise_clip = 0.5 # Maximum value of the Gaussian noise added to the actions (policy)
policy_freq = 2 # Number of iterations to wait before the policy network (Actor model) is updated

# %% [markdown]
# ## We create a file name for the two saved models: the Actor and Critic models

# %%
file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")
# Out:
# ---------------------------------------
# Settings: TD3_Walker2DBulletEnv-v0_0
# ---------------------------------------

# %% [markdown]
# ## We create a folder inside which will be saved the trained models

# %%
if not os.path.exists("./results"):
  os.makedirs("./results")
if save_models and not os.path.exists("./pytorch_models"):
  os.makedirs("./pytorch_models")

# %% [markdown]
# ## We create the PyBullet environment

# %%
env = gym.make(env_name)

# %% [markdown]
# ## We set seeds and we get the necessary information on the states and actions in the chosen environment

# %%
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# %% [markdown]
# ## We create the policy network (the Actor model)

# %%
policy = TD3(state_dim, action_dim, max_action)

# %% [markdown]
# ## We create the Experience Replay memory

# %%
replay_buffer = ReplayBuffer()

# %% [markdown]
# ## We define a list where all the evaluation results over 10 episodes are stored

# %%
evaluations = [evaluate_policy(policy)]
# Out:
# ---------------------------------------
# Average Reward over the Evaluation Step: 165.388923
# ---------------------------------------

# %% [markdown]
# ## We create a new folder directory in which the final results (videos of the agent) will be populated

# %%
def mkdir(base, name):
    path = os.path.join(base, name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path
work_dir = mkdir('exp', 'brs')
monitor_dir = mkdir(work_dir, 'monitor')
max_episode_steps = env._max_episode_steps
save_env_vid = False
if save_env_vid:
  env = wrappers.Monitor(env, monitor_dir, force = True)
  env.reset()

# %% [markdown]
# ## We initialize the variables

# %%
total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True
t0 = time.time()

# %% [markdown]
# ## Training

# %%
# We start the main loop over 500,000 timesteps
while total_timesteps < max_timesteps:
  
  # If the episode is done
  if done:

    # If we are not at the very beginning, we start the training process of the model
    if total_timesteps != 0:
      print("Total Timesteps: {} Episode Num: {} Reward: {}".format(total_timesteps, episode_num, episode_reward))
      policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)

    # We evaluate the episode and we save the policy
    if timesteps_since_eval >= eval_freq:
      timesteps_since_eval %= eval_freq
      evaluations.append(evaluate_policy(policy))
      policy.save(file_name, directory="./pytorch_models")
      np.save("./results/%s" % (file_name), evaluations)
    
    # When the training step is done, we reset the state of the environment
    obs = env.reset()
    
    # Set the Done to False
    done = False
    
    # Set rewards and episode timesteps to zero
    episode_reward = 0
    episode_timesteps = 0
    episode_num += 1
  
  # Before 10000 timesteps, we play random actions
  if total_timesteps < start_timesteps:
    action = env.action_space.sample()
  else: # After 10000 timesteps, we switch to the model
    action = policy.select_action(np.array(obs))
    # If the explore_noise parameter is not 0, we add noise to the action and we clip it
    if expl_noise != 0:
      action = (action + np.random.normal(0, expl_noise, size=env.action_space.shape[0])).clip(env.action_space.low, env.action_space.high)
  
  # The agent performs the action in the environment, then reaches the next state and receives the reward
  new_obs, reward, done, _ = env.step(action)
  
  # We check if the episode is done
  done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)
  
  # We increase the total reward
  episode_reward += reward
  
  # We store the new transition into the Experience Replay memory (ReplayBuffer)
  replay_buffer.add((obs, new_obs, action, reward, done_bool))

  # We update the state, the episode timestep, the total timesteps, and the timesteps since the evaluation of the policy
  obs = new_obs
  episode_timesteps += 1
  total_timesteps += 1
  timesteps_since_eval += 1

# We add the last policy evaluation to our list of evaluations and we save our model
evaluations.append(evaluate_policy(policy))
if save_models: policy.save("%s" % (file_name), directory="./pytorch_models")
np.save("./results/%s" % (file_name), evaluations)
# Out:
# Total Timesteps: 12 Episode Num: 1 Reward: 16.477399708874874
# Total Timesteps: 36 Episode Num: 2 Reward: 24.88393510267342
# Total Timesteps: 43 Episode Num: 3 Reward: 12.392115541822568
# Total Timesteps: 59 Episode Num: 4 Reward: 17.783260920888278
# Total Timesteps: 71 Episode Num: 5 Reward: 15.068369330670976
# Total Timesteps: 86 Episode Num: 6 Reward: 15.111720506289563
# Total Timesteps: 99 Episode Num: 7 Reward: 16.636259742081165
# Total Timesteps: 118 Episode Num: 8 Reward: 21.9553900300336
# Total Timesteps: 136 Episode Num: 9 Reward: 20.422054388804824
# Total Timesteps: 154 Episode Num: 10 Reward: 18.659647754002073
# Total Timesteps: 163 Episode Num: 11 Reward: 13.863004379814083
# Total Timesteps: 176 Episode Num: 12 Reward: 12.906176291809242
# Total Timesteps: 189 Episode Num: 13 Reward: 14.421033585270923
# Total Timesteps: 203 Episode Num: 14 Reward: 17.81478206675529
# Total Timesteps: 212 Episode Num: 15 Reward: 13.61993933978374
# Total Timesteps: 223 Episode Num: 16 Reward: 14.55615020244004
# Total Timesteps: 239 Episode Num: 17 Reward: 15.94246883974847
# Total Timesteps: 264 Episode Num: 18 Reward: 20.925844852747108
# Total Timesteps: 278 Episode Num: 19 Reward: 18.101190513995242
# Total Timesteps: 292 Episode Num: 20 Reward: 14.904429576388791
# Total Timesteps: 318 Episode Num: 21 Reward: 24.53558933289459
# Total Timesteps: 339 Episode Num: 22 Reward: 18.37826461103978
# Total Timesteps: 367 Episode Num: 23 Reward: 25.1050393305326
# Total Timesteps: 384 Episode Num: 24 Reward: 15.982271396750003
# Total Timesteps: 395 Episode Num: 25 Reward: 15.683034608575689
# Total Timesteps: 409 Episode Num: 26 Reward: 15.90326385886292
# Total Timesteps: 418 Episode Num: 27 Reward: 13.67607672112499
# Total Timesteps: 432 Episode Num: 28 Reward: 16.244816626406102
# Total Timesteps: 445 Episode Num: 29 Reward: 17.38022277511045
# Total Timesteps: 457 Episode Num: 30 Reward: 14.065329144214045
# Total Timesteps: 466 Episode Num: 31 Reward: 13.679193671785468
# Total Timesteps: 475 Episode Num: 32 Reward: 12.59408253430738
# Total Timesteps: 493 Episode Num: 33 Reward: 20.92137861133524
# Total Timesteps: 507 Episode Num: 34 Reward: 17.950423176708863
# Total Timesteps: 521 Episode Num: 35 Reward: 19.17574100861384
# Total Timesteps: 529 Episode Num: 36 Reward: 12.948581786008434
# Total Timesteps: 547 Episode Num: 37 Reward: 20.560500910699194
# Total Timesteps: 560 Episode Num: 38 Reward: 17.288329239621817
# Total Timesteps: 569 Episode Num: 39 Reward: 14.13381276762375
# Total Timesteps: 587 Episode Num: 40 Reward: 18.551722380213324
# Total Timesteps: 601 Episode Num: 41 Reward: 15.860077563258526
# Total Timesteps: 615 Episode Num: 42 Reward: 17.416517827768985
# Total Timesteps: 1239 Episode Num: 87 Reward: 13.383467118082626
# Total Timesteps: 1253 Episode Num: 88 Reward: 17.062416992432553
# Total Timesteps: 1265 Episode Num: 89 Reward: 15.271562883887961
# Total Timesteps: 1281 Episode Num: 90 Reward: 17.48621623671206
# Total Timesteps: 1295 Episode Num: 91 Reward: 17.58971844099578
# Total Timesteps: 1307 Episode Num: 92 Reward: 15.390651121856353
# Total Timesteps: 1316 Episode Num: 93 Reward: 13.687393150852582
# Total Timesteps: 1337 Episode Num: 94 Reward: 16.302943767982647
# Total Timesteps: 1355 Episode Num: 95 Reward: 19.817548335983886
# Total Timesteps: 1380 Episode Num: 96 Reward: 17.350900271390856
# Total Timesteps: 1395 Episode Num: 97 Reward: 17.40900473895017
# Total Timesteps: 1403 Episode Num: 98 Reward: 12.43434512970998
# Total Timesteps: 1426 Episode Num: 99 Reward: 18.201341948308986
# Total Timesteps: 1438 Episode Num: 100 Reward: 15.289962350032877
# Total Timesteps: 1469 Episode Num: 101 Reward: 27.671196025278178
# Total Timesteps: 1487 Episode Num: 102 Reward: 18.19390628155233
# Total Timesteps: 1497 Episode Num: 103 Reward: 14.206584796053354
# Total Timesteps: 1509 Episode Num: 104 Reward: 15.995242393288937
# Total Timesteps: 1523 Episode Num: 105 Reward: 13.790140588041687
# Total Timesteps: 1539 Episode Num: 106 Reward: 20.488000554074826
# Total Timesteps: 1551 Episode Num: 107 Reward: 14.508143700350772
# Total Timesteps: 1562 Episode Num: 108 Reward: 14.116987531160701
# Total Timesteps: 1573 Episode Num: 109 Reward: 14.779521287453827
# Total Timesteps: 1604 Episode Num: 110 Reward: 24.83800455291494
# Total Timesteps: 1616 Episode Num: 111 Reward: 17.738539553812007
# Total Timesteps: 1625 Episode Num: 112 Reward: 13.032863005140099
# Total Timesteps: 1637 Episode Num: 113 Reward: 16.789147773601872
# Total Timesteps: 1652 Episode Num: 114 Reward: 18.095049989881222
# Total Timesteps: 1664 Episode Num: 115 Reward: 14.088766737918197
# Total Timesteps: 1692 Episode Num: 116 Reward: 26.57021878549422
# Total Timesteps: 1703 Episode Num: 117 Reward: 16.173858294861567
# Total Timesteps: 1717 Episode Num: 118 Reward: 18.07086411821656
# Total Timesteps: 1730 Episode Num: 119 Reward: 14.994904326430696
# Total Timesteps: 1743 Episode Num: 120 Reward: 16.84535297068651
# Total Timesteps: 1753 Episode Num: 121 Reward: 14.555688226566419
# Total Timesteps: 1767 Episode Num: 122 Reward: 16.668614116718526
# Total Timesteps: 1783 Episode Num: 123 Reward: 19.75486307962419
# Total Timesteps: 1793 Episode Num: 124 Reward: 14.339882572830538
# Total Timesteps: 1804 Episode Num: 125 Reward: 16.63218592113553
# Total Timesteps: 1815 Episode Num: 126 Reward: 17.581585306237685
# Total Timesteps: 1825 Episode Num: 127 Reward: 13.764513640690712
# Total Timesteps: 1835 Episode Num: 128 Reward: 14.381138937914512
# Total Timesteps: 1848 Episode Num: 129 Reward: 15.239055541032576
# Total Timesteps: 2542 Episode Num: 174 Reward: 17.325011687405638
# Total Timesteps: 2553 Episode Num: 175 Reward: 15.732439128767876
# Total Timesteps: 2564 Episode Num: 176 Reward: 16.651503373117887
# Total Timesteps: 2571 Episode Num: 177 Reward: 11.562685198678809
# Total Timesteps: 2589 Episode Num: 178 Reward: 19.528653731504164
# Total Timesteps: 2604 Episode Num: 179 Reward: 16.45463814810937
# Total Timesteps: 2613 Episode Num: 180 Reward: 14.406010185919875
# Total Timesteps: 2626 Episode Num: 181 Reward: 16.515775225900867
# Total Timesteps: 2662 Episode Num: 182 Reward: 30.414019882316644
# Total Timesteps: 2678 Episode Num: 183 Reward: 18.45182085741399
# Total Timesteps: 2698 Episode Num: 184 Reward: 20.861631623411085
# Total Timesteps: 2710 Episode Num: 185 Reward: 16.866016733807918
# Total Timesteps: 2728 Episode Num: 186 Reward: 19.2103900530783
# Total Timesteps: 2736 Episode Num: 187 Reward: 13.081169537124515
# Total Timesteps: 2753 Episode Num: 188 Reward: 22.16394400020508
# Total Timesteps: 2768 Episode Num: 189 Reward: 17.64133498983574
# Total Timesteps: 2782 Episode Num: 190 Reward: 17.236141659478015
# Total Timesteps: 2799 Episode Num: 191 Reward: 16.95827606792009
# Total Timesteps: 2814 Episode Num: 192 Reward: 18.02362585418596
# Total Timesteps: 2833 Episode Num: 193 Reward: 18.887788802148137
# Total Timesteps: 2847 Episode Num: 194 Reward: 16.549036297644484
# Total Timesteps: 2861 Episode Num: 195 Reward: 16.837750000580854
# Total Timesteps: 2868 Episode Num: 196 Reward: 11.126356266271614
# Total Timesteps: 2907 Episode Num: 197 Reward: 39.176827565162974
# Total Timesteps: 2921 Episode Num: 198 Reward: 16.689002480237104
# Total Timesteps: 2933 Episode Num: 199 Reward: 14.742978827746994
# Total Timesteps: 2950 Episode Num: 200 Reward: 19.506374516815413
# Total Timesteps: 2966 Episode Num: 201 Reward: 17.377423649845877
# Total Timesteps: 2979 Episode Num: 202 Reward: 15.496045923269413
# Total Timesteps: 2992 Episode Num: 203 Reward: 16.831230747143852
# Total Timesteps: 3003 Episode Num: 204 Reward: 16.164738103651324
# Total Timesteps: 3013 Episode Num: 205 Reward: 14.890533387723554
# Total Timesteps: 3023 Episode Num: 206 Reward: 15.37258863572788
# Total Timesteps: 3034 Episode Num: 207 Reward: 15.176619927842694
# Total Timesteps: 3050 Episode Num: 208 Reward: 15.794676531414733
# Total Timesteps: 3062 Episode Num: 209 Reward: 15.460916222580998
# Total Timesteps: 3071 Episode Num: 210 Reward: 14.33533936672611
# Total Timesteps: 3091 Episode Num: 211 Reward: 14.839320297983065
# Total Timesteps: 3102 Episode Num: 212 Reward: 13.655223094575923
# Total Timesteps: 3117 Episode Num: 213 Reward: 19.571272016213335
# Total Timesteps: 3130 Episode Num: 214 Reward: 15.981188132088572
# Total Timesteps: 3145 Episode Num: 215 Reward: 18.230217046798497
# Total Timesteps: 3161 Episode Num: 216 Reward: 17.96501224859967
# Total Timesteps: 8085 Episode Num: 564 Reward: 16.02348464882962
# Total Timesteps: 8097 Episode Num: 565 Reward: 16.160278305631074
# Total Timesteps: 8114 Episode Num: 566 Reward: 20.60905501888337
# Total Timesteps: 8127 Episode Num: 567 Reward: 14.965328030895034
# Total Timesteps: 8138 Episode Num: 568 Reward: 13.798551452295214
# Total Timesteps: 8150 Episode Num: 569 Reward: 17.010566202655898
# Total Timesteps: 8160 Episode Num: 570 Reward: 14.686033746239262
# Total Timesteps: 8176 Episode Num: 571 Reward: 16.02622134758858
# Total Timesteps: 8191 Episode Num: 572 Reward: 16.233832022664135
# Total Timesteps: 8204 Episode Num: 573 Reward: 17.46912979075714
# Total Timesteps: 8214 Episode Num: 574 Reward: 15.35706272140087
# Total Timesteps: 8226 Episode Num: 575 Reward: 16.180710034418734
# Total Timesteps: 8257 Episode Num: 576 Reward: 24.10689557118021
# Total Timesteps: 8268 Episode Num: 577 Reward: 14.858324059497681
# Total Timesteps: 8279 Episode Num: 578 Reward: 14.585141799553822
# Total Timesteps: 8297 Episode Num: 579 Reward: 18.913032474934884
# Total Timesteps: 8312 Episode Num: 580 Reward: 15.020100567112966
# Total Timesteps: 8332 Episode Num: 581 Reward: 18.495683928047942
# Total Timesteps: 8353 Episode Num: 582 Reward: 17.5256132452836
# Total Timesteps: 8369 Episode Num: 583 Reward: 18.368495157154396
# Total Timesteps: 8384 Episode Num: 584 Reward: 14.228929134130885
# Total Timesteps: 8394 Episode Num: 585 Reward: 15.463624564130441
# Total Timesteps: 8407 Episode Num: 586 Reward: 16.30593167168699
# Total Timesteps: 8422 Episode Num: 587 Reward: 18.455511259332706
# Total Timesteps: 8444 Episode Num: 588 Reward: 20.470307191048047
# Total Timesteps: 8454 Episode Num: 589 Reward: 15.20534907379624
# Total Timesteps: 8468 Episode Num: 590 Reward: 17.808290691455475
# Total Timesteps: 8478 Episode Num: 591 Reward: 15.010368708279564
# Total Timesteps: 8499 Episode Num: 592 Reward: 17.94907821977249
# Total Timesteps: 8515 Episode Num: 593 Reward: 18.791568278610065
# Total Timesteps: 8533 Episode Num: 594 Reward: 19.853350724677142
# Total Timesteps: 8553 Episode Num: 595 Reward: 16.92170621999103
# Total Timesteps: 8562 Episode Num: 596 Reward: 13.143953467554818
# Total Timesteps: 8572 Episode Num: 597 Reward: 13.887856539274798
# Total Timesteps: 8582 Episode Num: 598 Reward: 12.522854817641202
# Total Timesteps: 8597 Episode Num: 599 Reward: 17.970294916514828
# Total Timesteps: 8610 Episode Num: 600 Reward: 15.783764536456147
# Total Timesteps: 8619 Episode Num: 601 Reward: 14.621626848555751
# Total Timesteps: 8627 Episode Num: 602 Reward: 13.620961775515752
# Total Timesteps: 8641 Episode Num: 603 Reward: 15.742386833232013
# Total Timesteps: 8649 Episode Num: 604 Reward: 13.564161188622528
# Total Timesteps: 8664 Episode Num: 605 Reward: 20.310925660895013
# Total Timesteps: 8676 Episode Num: 606 Reward: 16.614749669929733
# Total Timesteps: 8690 Episode Num: 607 Reward: 16.68632995764929
# Total Timesteps: 9849 Episode Num: 695 Reward: 15.94426746030513
# Total Timesteps: 9869 Episode Num: 696 Reward: 21.51658194509655
# Total Timesteps: 9888 Episode Num: 697 Reward: 20.614336004646614
# Total Timesteps: 9909 Episode Num: 698 Reward: 21.085438692544994
# Total Timesteps: 9925 Episode Num: 699 Reward: 18.071330235688947
# Total Timesteps: 9938 Episode Num: 700 Reward: 11.740802761110535
# Total Timesteps: 9952 Episode Num: 701 Reward: 15.59157403844729
# Total Timesteps: 9966 Episode Num: 702 Reward: 16.871423387706454
# Total Timesteps: 9992 Episode Num: 703 Reward: 23.557104834562047
# Total Timesteps: 10000 Episode Num: 704 Reward: 12.569763983682787
# ---------------------------------------
# Average Reward over the Evaluation Step: 71.933368
# ---------------------------------------
# Total Timesteps: 10080 Episode Num: 705 Reward: 79.53037574189095
# Total Timesteps: 10141 Episode Num: 706 Reward: 62.97185977903815
# Total Timesteps: 10198 Episode Num: 707 Reward: 61.17193958691476
# Total Timesteps: 10264 Episode Num: 708 Reward: 63.92589452927596
# Total Timesteps: 10354 Episode Num: 709 Reward: 90.0219379032482
# Total Timesteps: 10428 Episode Num: 710 Reward: 71.49927940753466
# Total Timesteps: 10484 Episode Num: 711 Reward: 63.8311663382414
# Total Timesteps: 10556 Episode Num: 712 Reward: 75.30262251774865
# Total Timesteps: 10621 Episode Num: 713 Reward: 66.52591916801971
# Total Timesteps: 10700 Episode Num: 714 Reward: 74.71240423437388
# Total Timesteps: 10781 Episode Num: 715 Reward: 68.62546968628925
# Total Timesteps: 10852 Episode Num: 716 Reward: 66.44566187928714
# Total Timesteps: 10906 Episode Num: 717 Reward: 58.5191869162447
# Total Timesteps: 10961 Episode Num: 718 Reward: 57.685690818991084
# Total Timesteps: 11039 Episode Num: 719 Reward: 76.0736966915134
# Total Timesteps: 11113 Episode Num: 720 Reward: 70.00863763467287
# Total Timesteps: 11219 Episode Num: 721 Reward: 98.74663674135174
# Total Timesteps: 11315 Episode Num: 722 Reward: 86.70005163131509
# Total Timesteps: 11374 Episode Num: 723 Reward: 53.43383694445966
# Total Timesteps: 11445 Episode Num: 724 Reward: 59.29259709121671
# Total Timesteps: 11526 Episode Num: 725 Reward: 78.22860144461653
# Total Timesteps: 12526 Episode Num: 726 Reward: 780.870397532091
# Total Timesteps: 12583 Episode Num: 727 Reward: 68.02732866956363
# Total Timesteps: 12631 Episode Num: 728 Reward: 63.06905943739817
# Total Timesteps: 12688 Episode Num: 729 Reward: 74.31464028210587
# ...
# ---------------------------------------
# Total Timesteps: 341459 Episode Num: 1640 Reward: 1552.331328722622
# Total Timesteps: 342459 Episode Num: 1641 Reward: 1648.7200724924194
# Total Timesteps: 343459 Episode Num: 1642 Reward: 1617.8349523157613
# Total Timesteps: 344459 Episode Num: 1643 Reward: 1569.665319361712
# Total Timesteps: 344655 Episode Num: 1644 Reward: 293.51536173940184
# Total Timesteps: 345099 Episode Num: 1645 Reward: 740.6863365871222
# ---------------------------------------
# Average Reward over the Evaluation Step: 637.070063
# ---------------------------------------
# Total Timesteps: 345281 Episode Num: 1646 Reward: 287.13624511105
# Total Timesteps: 345685 Episode Num: 1647 Reward: 643.2267144734127
# Total Timesteps: 346685 Episode Num: 1648 Reward: 1621.3943988551944
# Total Timesteps: 347685 Episode Num: 1649 Reward: 1508.9645017808582
# Total Timesteps: 348685 Episode Num: 1650 Reward: 1563.4229805749983
# Total Timesteps: 349661 Episode Num: 1651 Reward: 1503.3411391117104
# Total Timesteps: 350661 Episode Num: 1652 Reward: 1617.7297290695979
# ---------------------------------------
# Average Reward over the Evaluation Step: 1583.377772
# ---------------------------------------
# Total Timesteps: 350821 Episode Num: 1653 Reward: 247.66087229009727
# Total Timesteps: 351821 Episode Num: 1654 Reward: 1603.9548882813917
# Total Timesteps: 352821 Episode Num: 1655 Reward: 1567.9156875770564
# Total Timesteps: 353821 Episode Num: 1656 Reward: 1626.5862367017983
# Total Timesteps: 354821 Episode Num: 1657 Reward: 1566.4086215494651
# Total Timesteps: 355821 Episode Num: 1658 Reward: 1702.5882878784887
# ---------------------------------------
# Average Reward over the Evaluation Step: 1508.432094
# ---------------------------------------
# Total Timesteps: 356821 Episode Num: 1659 Reward: 1665.5152100917123
# Total Timesteps: 357821 Episode Num: 1660 Reward: 1630.5914863296514
# Total Timesteps: 358821 Episode Num: 1661 Reward: 1717.1844599614851
# Total Timesteps: 359821 Episode Num: 1662 Reward: 1605.8002650671363
# Total Timesteps: 360821 Episode Num: 1663 Reward: 1656.8203931494793
# ---------------------------------------
# Average Reward over the Evaluation Step: 1343.724129
# ---------------------------------------
# Total Timesteps: 361821 Episode Num: 1664 Reward: 1588.7084113989736
# Total Timesteps: 362821 Episode Num: 1665 Reward: 1558.7031303932438
# Total Timesteps: 362997 Episode Num: 1666 Reward: 267.0634301004186
# Total Timesteps: 363997 Episode Num: 1667 Reward: 1651.2150815524215
# Total Timesteps: 364997 Episode Num: 1668 Reward: 1646.8504897811326
# Total Timesteps: 365997 Episode Num: 1669 Reward: 1530.8786893289898
# ---------------------------------------
# Average Reward over the Evaluation Step: 1612.755958
# ---------------------------------------
# Total Timesteps: 366997 Episode Num: 1670 Reward: 1620.5363004505725
# Total Timesteps: 367997 Episode Num: 1671 Reward: 1621.9221594241449
# Total Timesteps: 368997 Episode Num: 1672 Reward: 1547.9165385528283
# Total Timesteps: 369997 Episode Num: 1673 Reward: 1580.5711010543114
# Total Timesteps: 370997 Episode Num: 1674 Reward: 1567.7946834597096
# ---------------------------------------
# Average Reward over the Evaluation Step: 1636.122753
# ---------------------------------------
# Total Timesteps: 371997 Episode Num: 1675 Reward: 1621.400323634637
# Total Timesteps: 372997 Episode Num: 1676 Reward: 1710.1740631444459
# Total Timesteps: 373997 Episode Num: 1677 Reward: 1665.2746378975514
# Total Timesteps: 374997 Episode Num: 1678 Reward: 1724.1100009738102
# Total Timesteps: 375997 Episode Num: 1679 Reward: 1722.9973727050826
# ---------------------------------------
# Average Reward over the Evaluation Step: 1788.946836
# ---------------------------------------
# Total Timesteps: 376997 Episode Num: 1680 Reward: 1736.7216839567895
# Total Timesteps: 377997 Episode Num: 1681 Reward: 1720.9181354940047
# Total Timesteps: 378864 Episode Num: 1682 Reward: 1419.139799761579
# Total Timesteps: 379864 Episode Num: 1683 Reward: 1576.839328666292
# Total Timesteps: 380864 Episode Num: 1684 Reward: 986.8103524686119
# ---------------------------------------
# Average Reward over the Evaluation Step: 1427.088242
# ---------------------------------------
# Total Timesteps: 381864 Episode Num: 1685 Reward: 1070.907595715745
# Total Timesteps: 382864 Episode Num: 1686 Reward: 1726.7812055748543
# Total Timesteps: 383864 Episode Num: 1687 Reward: 816.3824218270472
# Total Timesteps: 384864 Episode Num: 1688 Reward: 1699.0159137371124
# Total Timesteps: 385864 Episode Num: 1689 Reward: 1806.184103539066
# ---------------------------------------
# Average Reward over the Evaluation Step: 1660.379003
# ---------------------------------------
# Total Timesteps: 386864 Episode Num: 1690 Reward: 1617.3918183130768
# Total Timesteps: 387864 Episode Num: 1691 Reward: 1628.4042317232947
# Total Timesteps: 388864 Episode Num: 1692 Reward: 1706.72856687225
# Total Timesteps: 389864 Episode Num: 1693 Reward: 1720.0357292941476
# Total Timesteps: 390130 Episode Num: 1694 Reward: 417.33132490120704
# ---------------------------------------
# Average Reward over the Evaluation Step: 1309.216824
# ---------------------------------------
# Total Timesteps: 390908 Episode Num: 1695 Reward: 1205.4515763602396
# Total Timesteps: 391179 Episode Num: 1696 Reward: 438.7665456163882
# Total Timesteps: 392179 Episode Num: 1697 Reward: 1727.5165079937526
# Total Timesteps: 393179 Episode Num: 1698 Reward: 1594.9976390204051
# Total Timesteps: 393955 Episode Num: 1699 Reward: 1180.3398693073952
# Total Timesteps: 394955 Episode Num: 1700 Reward: 1706.4651627682942
# Total Timesteps: 395955 Episode Num: 1701 Reward: 1590.945709539835
# ---------------------------------------
# Average Reward over the Evaluation Step: 1565.270761
# ---------------------------------------
# Total Timesteps: 396955 Episode Num: 1702 Reward: 1548.80733874737
# Total Timesteps: 397955 Episode Num: 1703 Reward: 1601.3181778038042
# Total Timesteps: 398955 Episode Num: 1704 Reward: 1688.4742849218937
# Total Timesteps: 399955 Episode Num: 1705 Reward: 1779.9004784061274
# Total Timesteps: 400955 Episode Num: 1706 Reward: 1791.157238677167
# ---------------------------------------
# Average Reward over the Evaluation Step: 1779.894376
# ---------------------------------------
# Total Timesteps: 401955 Episode Num: 1707 Reward: 1750.174528306408
# Total Timesteps: 402955 Episode Num: 1708 Reward: 1743.8122496990707
# Total Timesteps: 403955 Episode Num: 1709 Reward: 1739.1160569637163
# Total Timesteps: 404955 Episode Num: 1710 Reward: 1813.6031753086236
# Total Timesteps: 405955 Episode Num: 1711 Reward: 1719.4086539268308
# ---------------------------------------
# Average Reward over the Evaluation Step: 1790.297038
# ---------------------------------------
# Total Timesteps: 406955 Episode Num: 1712 Reward: 1747.1139837768874
# Total Timesteps: 407955 Episode Num: 1713 Reward: 1634.9188180259189
# Total Timesteps: 408955 Episode Num: 1714 Reward: 1680.1794595343215
# Total Timesteps: 409955 Episode Num: 1715 Reward: 1701.5428969968116
# Total Timesteps: 410955 Episode Num: 1716 Reward: 1687.7238438134875
# ---------------------------------------
# Average Reward over the Evaluation Step: 1718.193605
# ---------------------------------------
# Total Timesteps: 411955 Episode Num: 1717 Reward: 1719.4017058634943
# Total Timesteps: 412955 Episode Num: 1718 Reward: 1770.1249165107934
# Total Timesteps: 413955 Episode Num: 1719 Reward: 1636.4906551161316
# Total Timesteps: 414955 Episode Num: 1720 Reward: 1745.656476694048
# Total Timesteps: 415891 Episode Num: 1721 Reward: 1604.9621327471966
# ---------------------------------------
# Average Reward over the Evaluation Step: 1543.967703
# ---------------------------------------
# Total Timesteps: 416684 Episode Num: 1722 Reward: 1336.167688169819
# Total Timesteps: 417684 Episode Num: 1723 Reward: 1736.5583735103007
# Total Timesteps: 418684 Episode Num: 1724 Reward: 1663.2831205716927
# Total Timesteps: 419684 Episode Num: 1725 Reward: 1814.349963223895
# Total Timesteps: 420684 Episode Num: 1726 Reward: 1710.4767613145455
# ---------------------------------------
# Average Reward over the Evaluation Step: 1749.135653
# ---------------------------------------
# Total Timesteps: 421684 Episode Num: 1727 Reward: 1753.616177907073
# Total Timesteps: 422684 Episode Num: 1728 Reward: 1645.087010930158
# Total Timesteps: 423684 Episode Num: 1729 Reward: 1710.4666875513544
# Total Timesteps: 424684 Episode Num: 1730 Reward: 1634.6010971148726
# Total Timesteps: 425684 Episode Num: 1731 Reward: 1688.1350175498765
# ---------------------------------------
# Average Reward over the Evaluation Step: 1746.533314
# ---------------------------------------
# Total Timesteps: 426684 Episode Num: 1732 Reward: 1693.059970435911
# Total Timesteps: 427684 Episode Num: 1733 Reward: 1664.7939007864013
# Total Timesteps: 428684 Episode Num: 1734 Reward: 1742.1446715389297
# Total Timesteps: 429684 Episode Num: 1735 Reward: 1752.9541934508825
# Total Timesteps: 430684 Episode Num: 1736 Reward: 1711.257609263776
# ---------------------------------------
# Average Reward over the Evaluation Step: 1879.952843
# ---------------------------------------
# Total Timesteps: 431684 Episode Num: 1737 Reward: 1828.676719659497
# Total Timesteps: 432684 Episode Num: 1738 Reward: 1639.4851607427913
# Total Timesteps: 433684 Episode Num: 1739 Reward: 1493.4019762902042
# Total Timesteps: 434684 Episode Num: 1740 Reward: 1738.7189618011798
# Total Timesteps: 435684 Episode Num: 1741 Reward: 1806.3628407775445
# ---------------------------------------
# Average Reward over the Evaluation Step: 1798.545145
# ---------------------------------------
# Total Timesteps: 436684 Episode Num: 1742 Reward: 1792.387518828982
# Total Timesteps: 437684 Episode Num: 1743 Reward: 1890.0266138388108
# Total Timesteps: 438684 Episode Num: 1744 Reward: 1799.907502419049
# Total Timesteps: 439684 Episode Num: 1745 Reward: 1753.8425370881473
# Total Timesteps: 440684 Episode Num: 1746 Reward: 1732.6246374516757
# ---------------------------------------
# Average Reward over the Evaluation Step: 1800.510571
# ---------------------------------------
# Total Timesteps: 441684 Episode Num: 1747 Reward: 1747.3143565131793
# Total Timesteps: 442684 Episode Num: 1748 Reward: 1711.2460299790775
# Total Timesteps: 443684 Episode Num: 1749 Reward: 1866.8898945984238
# Total Timesteps: 444684 Episode Num: 1750 Reward: 1743.3086214030795
# Total Timesteps: 444908 Episode Num: 1751 Reward: 365.31170763302157
# Total Timesteps: 445908 Episode Num: 1752 Reward: 1777.437583127755
# ---------------------------------------
# Average Reward over the Evaluation Step: 1835.718218
# ---------------------------------------
# Total Timesteps: 446908 Episode Num: 1753 Reward: 1759.1330608034912
# Total Timesteps: 447908 Episode Num: 1754 Reward: 1785.922003255714
# Total Timesteps: 448908 Episode Num: 1755 Reward: 1752.6260475542088
# Total Timesteps: 449908 Episode Num: 1756 Reward: 1757.1278575501292
# Total Timesteps: 450908 Episode Num: 1757 Reward: 1796.8348409141563
# ---------------------------------------
# Average Reward over the Evaluation Step: 1842.784114
# ---------------------------------------
# Total Timesteps: 451908 Episode Num: 1758 Reward: 1825.1954177252487
# Total Timesteps: 452908 Episode Num: 1759 Reward: 1798.6348150103763
# Total Timesteps: 453908 Episode Num: 1760 Reward: 1881.8709126130263
# Total Timesteps: 454908 Episode Num: 1761 Reward: 1715.8833132950274
# Total Timesteps: 455908 Episode Num: 1762 Reward: 1911.1082073593711
# ---------------------------------------
# Average Reward over the Evaluation Step: 1927.807053
# ---------------------------------------
# Total Timesteps: 456908 Episode Num: 1763 Reward: 1897.8040603998506
# Total Timesteps: 457908 Episode Num: 1764 Reward: 1833.8052279095816
# Total Timesteps: 458908 Episode Num: 1765 Reward: 1876.8106273645092
# Total Timesteps: 459908 Episode Num: 1766 Reward: 1730.619928756783
# Total Timesteps: 460548 Episode Num: 1767 Reward: 1029.210550185036
# ---------------------------------------
# Average Reward over the Evaluation Step: 812.131350
# ---------------------------------------
# Total Timesteps: 460756 Episode Num: 1768 Reward: 338.0638016134848
# Total Timesteps: 461756 Episode Num: 1769 Reward: 1913.230325012993
# Total Timesteps: 462756 Episode Num: 1770 Reward: 1969.7402177900478
# Total Timesteps: 463756 Episode Num: 1771 Reward: 1883.6406392204376
# Total Timesteps: 464756 Episode Num: 1772 Reward: 1813.5955639856875
# Total Timesteps: 465756 Episode Num: 1773 Reward: 1828.104221467166
# ---------------------------------------
# Average Reward over the Evaluation Step: 1858.038912
# ---------------------------------------
# Total Timesteps: 466756 Episode Num: 1774 Reward: 1825.4045174763949
# Total Timesteps: 467756 Episode Num: 1775 Reward: 1817.8562898851364
# Total Timesteps: 468756 Episode Num: 1776 Reward: 1790.6125097409972
# Total Timesteps: 469756 Episode Num: 1777 Reward: 1809.44123828376
# Total Timesteps: 470756 Episode Num: 1778 Reward: 1740.1122641000325
# ---------------------------------------
# Average Reward over the Evaluation Step: 1875.083334
# ---------------------------------------
# Total Timesteps: 471756 Episode Num: 1779 Reward: 1848.7332704730259
# Total Timesteps: 472756 Episode Num: 1780 Reward: 1750.3965062144637
# Total Timesteps: 473756 Episode Num: 1781 Reward: 1685.7557443211547
# Total Timesteps: 474756 Episode Num: 1782 Reward: 1596.9717135688609
# Total Timesteps: 475756 Episode Num: 1783 Reward: 1729.6705368181083
# ---------------------------------------
# Average Reward over the Evaluation Step: 1697.411003
# ---------------------------------------
# Total Timesteps: 476756 Episode Num: 1784 Reward: 1665.3382063736854
# Total Timesteps: 477756 Episode Num: 1785 Reward: 1855.5069502310541
# Total Timesteps: 478756 Episode Num: 1786 Reward: 1833.8729937615349
# Total Timesteps: 479756 Episode Num: 1787 Reward: 1827.7662754500582
# Total Timesteps: 480756 Episode Num: 1788 Reward: 1917.082552274891
# ---------------------------------------
# Average Reward over the Evaluation Step: 1862.540924
# ---------------------------------------
# Total Timesteps: 481756 Episode Num: 1789 Reward: 1874.7331608709962
# Total Timesteps: 482756 Episode Num: 1790 Reward: 1817.6416088172537
# Total Timesteps: 483756 Episode Num: 1791 Reward: 1694.8274276529569
# Total Timesteps: 484756 Episode Num: 1792 Reward: 1730.8998285649889
# Total Timesteps: 485756 Episode Num: 1793 Reward: 1869.4399286277028
# ---------------------------------------
# Average Reward over the Evaluation Step: 1837.526364
# ---------------------------------------
# Total Timesteps: 486756 Episode Num: 1794 Reward: 1792.732579105267
# Total Timesteps: 487756 Episode Num: 1795 Reward: 1672.425062006291
# Total Timesteps: 488756 Episode Num: 1796 Reward: 1791.4336493656099
# Total Timesteps: 489756 Episode Num: 1797 Reward: 1858.6490383761154
# Total Timesteps: 490756 Episode Num: 1798 Reward: 1908.744218220217
# ---------------------------------------
# Average Reward over the Evaluation Step: 1893.452865
# ---------------------------------------
# Total Timesteps: 491756 Episode Num: 1799 Reward: 1823.5899587061083
# Total Timesteps: 492756 Episode Num: 1800 Reward: 1838.5045985553977
# Total Timesteps: 493756 Episode Num: 1801 Reward: 1735.9711961836745
# Total Timesteps: 494536 Episode Num: 1802 Reward: 1235.4335155497863
# Total Timesteps: 495536 Episode Num: 1803 Reward: 1786.8826212954514
# ---------------------------------------
# Average Reward over the Evaluation Step: 1779.481492
# ---------------------------------------
# Total Timesteps: 496536 Episode Num: 1804 Reward: 1781.7810230833309
# Total Timesteps: 496871 Episode Num: 1805 Reward: 581.2092753079427
# Total Timesteps: 496981 Episode Num: 1806 Reward: 164.16781595634325
# Total Timesteps: 497981 Episode Num: 1807 Reward: 1686.1538912576204
# Total Timesteps: 498981 Episode Num: 1808 Reward: 1635.4785599679642
# Total Timesteps: 499981 Episode Num: 1809 Reward: 1755.9211620184121
# ---------------------------------------
# Average Reward over the Evaluation Step: 1804.972923
# ---------------------------------------

# %% [markdown]
# ## Inference

# %%
class Actor(nn.Module):
  
  def __init__(self, state_dim, action_dim, max_action):
    super(Actor, self).__init__()
    self.layer_1 = nn.Linear(state_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, action_dim)
    self.max_action = max_action

  def forward(self, x):
    x = F.relu(self.layer_1(x))
    x = F.relu(self.layer_2(x))
    x = self.max_action * torch.tanh(self.layer_3(x)) 
    return x

class Critic(nn.Module):
  
  def __init__(self, state_dim, action_dim):
    super(Critic, self).__init__()
    # Defining the first Critic neural network
    self.layer_1 = nn.Linear(state_dim + action_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, 1)
    # Defining the second Critic neural network
    self.layer_4 = nn.Linear(state_dim + action_dim, 400)
    self.layer_5 = nn.Linear(400, 300)
    self.layer_6 = nn.Linear(300, 1)

  def forward(self, x, u):
    xu = torch.cat([x, u], 1)
    # Forward-Propagation on the first Critic Neural Network
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    # Forward-Propagation on the second Critic Neural Network
    x2 = F.relu(self.layer_4(xu))
    x2 = F.relu(self.layer_5(x2))
    x2 = self.layer_6(x2)
    return x1, x2

  def Q1(self, x, u):
    xu = torch.cat([x, u], 1)
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    return x1

# Selecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Building the whole Training Process into a class

class TD3(object):
  
  def __init__(self, state_dim, action_dim, max_action):
    self.actor = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target.load_state_dict(self.actor.state_dict())
    self.actor_optimizer = torch.optim.Adam(self.actor.parameters())
    self.critic = Critic(state_dim, action_dim).to(device)
    self.critic_target = Critic(state_dim, action_dim).to(device)
    self.critic_target.load_state_dict(self.critic.state_dict())
    self.critic_optimizer = torch.optim.Adam(self.critic.parameters())
    self.max_action = max_action

  def select_action(self, state):
    state = torch.Tensor(state.reshape(1, -1)).to(device)
    return self.actor(state).cpu().data.numpy().flatten()

  def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
    
    for it in range(iterations):
      
      # Step 4: We sample a batch of transitions (s, s’, a, r) from the memory
      batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
      state = torch.Tensor(batch_states).to(device)
      next_state = torch.Tensor(batch_next_states).to(device)
      action = torch.Tensor(batch_actions).to(device)
      reward = torch.Tensor(batch_rewards).to(device)
      done = torch.Tensor(batch_dones).to(device)
      
      # Step 5: From the next state s’, the Actor target plays the next action a’
      next_action = self.actor_target(next_state)
      
      # Step 6: We add Gaussian noise to this next action a’ and we clamp it in a range of values supported by the environment
      noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
      noise = noise.clamp(-noise_clip, noise_clip)
      next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
      
      # Step 7: The two Critic targets take each the couple (s’, a’) as input and return two Q-values Qt1(s’,a’) and Qt2(s’,a’) as outputs
      target_Q1, target_Q2 = self.critic_target(next_state, next_action)
      
      # Step 8: We keep the minimum of these two Q-values: min(Qt1, Qt2)
      target_Q = torch.min(target_Q1, target_Q2)
      
      # Step 9: We get the final target of the two Critic models, which is: Qt = r + γ * min(Qt1, Qt2), where γ is the discount factor
      target_Q = reward + ((1 - done) * discount * target_Q).detach()
      
      # Step 10: The two Critic models take each the couple (s, a) as input and return two Q-values Q1(s,a) and Q2(s,a) as outputs
      current_Q1, current_Q2 = self.critic(state, action)
      
      # Step 11: We compute the loss coming from the two Critic models: Critic Loss = MSE_Loss(Q1(s,a), Qt) + MSE_Loss(Q2(s,a), Qt)
      critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
      
      # Step 12: We backpropagate this Critic loss and update the parameters of the two Critic models with a SGD optimizer
      self.critic_optimizer.zero_grad()
      critic_loss.backward()
      self.critic_optimizer.step()
      
      # Step 13: Once every two iterations, we update our Actor model by performing gradient ascent on the output of the first Critic model
      if it % policy_freq == 0:
        actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        # Step 14: Still once every two iterations, we update the weights of the Actor target by polyak averaging
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
        
        # Step 15: Still once every two iterations, we update the weights of the Critic target by polyak averaging
        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
  
  # Making a save method to save a trained model
  def save(self, filename, directory):
    torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, filename))
    torch.save(self.critic.state_dict(), '%s/%s_critic.pth' % (directory, filename))
  
  # Making a load method to load a pre-trained model
  def load(self, filename, directory):
    self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, filename)))
    self.critic.load_state_dict(torch.load('%s/%s_critic.pth' % (directory, filename)))

def evaluate_policy(policy, eval_episodes=10):
  avg_reward = 0.
  for _ in range(eval_episodes):
    obs = env.reset()
    done = False
    while not done:
      action = policy.select_action(np.array(obs))
      obs, reward, done, _ = env.step(action)
      avg_reward += reward
  avg_reward /= eval_episodes
  print ("---------------------------------------")
  print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
  print ("---------------------------------------")
  return avg_reward

env_name = "Walker2DBulletEnv-v0"
seed = 0

file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")

eval_episodes = 10
save_env_vid = True
env = gym.make(env_name)
max_episode_steps = env._max_episode_steps
if save_env_vid:
  env = wrappers.Monitor(env, monitor_dir, force = True)
  env.reset()
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
policy = TD3(state_dim, action_dim, max_action)
policy.load(file_name, './pytorch_models/')
_ = evaluate_policy(policy, eval_episodes=eval_episodes)
# Out:
# ---------------------------------------
# Settings: TD3_Walker2DBulletEnv-v0_0
# ---------------------------------------
