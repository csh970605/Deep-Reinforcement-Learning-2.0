# %% [markdown]
# # Twin-Delayed DDPG

# %% [markdown]
# ## Installing the packages

# %%
# !pip install pybullet
# !pip install gym==0.22.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pybullet
#   Downloading pybullet-3.2.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (91.7 MB)
#      |████████████████████████████████| 91.7 MB 99 kB/s
# Installing collected packages: pybullet
# Successfully installed pybullet-3.2.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gym==0.22.0
#   Downloading gym-0.22.0.tar.gz (631 kB)
#      |████████████████████████████████| 631 kB 4.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.22.0) (1.5.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.8/dist-packages (from gym==0.22.0) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.22.0) (4.13.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.22.0) (1.21.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.10.0->gym==0.22.0) (3.11.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (PEP 517) ... done
#   Created wheel for gym: filename=gym-0.22.0-py3-none-any.whl size=708396 sha256=7ec01e34f9cdf80ccfa3fc7857fdc1490f48b387893a0153f56371bb70b11183
#   Stored in directory: /root/.cache/pip/wheels/4d/6e/7d/0e050cb65b427dd0db5c5ab2c9a1f1ffa3d58db2f4db516268
# Successfully built gym
# Installing collected packages: gym
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# Successfully installed gym-0.22.0

# %% [markdown]
# ## Importing the libraries

# %%
import os
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import pybullet_envs
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
from gym import wrappers
from torch.autograd import Variable
from collections import deque

# %% [markdown]
# ## Step 1: We initialize the Experience Replay memory

# %%
class ReplayBuffer(object):

  # max_size : capacity of the memory(transition)
  def __init__(self, max_size=1e6):
    self.storage = [] # list of transition
    self.max_size = max_size
    self.ptr = 0 # pointer

  def add(self, transition):
    if len(self.storage) == self.max_size:
      # rebuild memory
      self.storage[int(self.ptr)] = transition
      self.ptr = (self.ptr + 1) % self.max_size
    else:
      self.storage.append(transition)

  # put trainsition into batch
  def sample(self, batch_size):
    ind = np.random.randint(0, len(self.storage), size=batch_size)
    batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = [], [], [], [], []
    for i in ind: 
      state, next_state, action, reward, done = self.storage[i]
      batch_states.append(np.array(state, copy=False))
      batch_next_states.append(np.array(next_state, copy=False))
      batch_actions.append(np.array(action, copy=False))
      batch_rewards.append(np.array(reward, copy=False))
      batch_dones.append(np.array(done, copy=False))
    return np.array(batch_states), np.array(batch_next_states), np.array(batch_actions), np.array(batch_rewards).reshape(-1, 1), np.array(batch_dones).reshape(-1, 1)

# %% [markdown]
# ## Step 2: We build one neural network for the Actor model and one neural network for the Actor target

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# state_dim -> 400 -> 300 -> action_dim
class Actor(nn.Module):
  
  # state_dim : number of components in the input state vector
  # action_dim : number of actions(outputs) played at the same time(T)
  # max_action : range of remembering to clip actions
  def __init__(self, state_dim, action_dim, max_action):
    super(Actor, self).__init__()
    self.layer_1 = nn.Linear(state_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, action_dim)
    self.max_action = max_action

  def forward(self, x):
    x = F.relu(self.layer_1(x))
    x = F.relu(self.layer_2(x))
    # why multiply self.max_action? : 
    # because -1 <torch.tanh < 1, makes action to go back to the original range of action values
    x = self.max_action * torch.tanh(self.layer_3(x))
    return x

# %% [markdown]
# ## Step 3: We build two neural networks for the two Critic models and two neural networks for the two Critic targets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Critic(nn.Module):
  
  def __init__(self, state_dim, action_dim):
    super(Critic, self).__init__()
    # Defining the first Critic neural network
    self.layer_1 = nn.Linear(state_dim + action_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, 1)
    # Defining the second Critic neural network
    self.layer_4 = nn.Linear(state_dim + action_dim, 400)
    self.layer_5 = nn.Linear(400, 300)
    self.layer_6 = nn.Linear(300, 1)

  def forward(self, x, u):
    xu = torch.cat([x, u], 1)
    # Forward-Propagation on the first Critic Neural Network
    x1 = F.relu(self.layer_1(xu)) # concatenation of the state(x) and action(u)
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    # Forward-Propagation on the second Critic Neural Network
    x2 = F.relu(self.layer_4(xu))
    x2 = F.relu(self.layer_5(x2))
    x2 = self.layer_6(x2)
    return x1, x2

  # return Q value output by the first critic
  def Q1(self, x, u):
    xu = torch.cat([x, u], 1)
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    return x1

# %% [markdown]
# ## Steps 4 to 15: Training Process

# %%
# Selecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Building the whole Training Process into a class

class TD3(object):
  
  def __init__(self, state_dim, action_dim, max_action):
    # build actor model
    self.actor = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target.load_state_dict(self.actor.state_dict()) # get state from actor model
    self.actor_optimizer = torch.optim.Adam(self.actor.parameters())
    # build critic model
    self.critic = Critic(state_dim, action_dim).to(device)
    self.critic_target = Critic(state_dim, action_dim).to(device)
    self.critic_target.load_state_dict(self.critic.state_dict()) # get state from actor critic
    self.critic_optimizer = torch.optim.Adam(self.critic.parameters())
    self.max_action = max_action

  # why return type is converted tensor to numpy? : to clip the action after adding noise
  def select_action(self, state):
    state = torch.Tensor(state.reshape(1, -1)).to(device)
    return self.actor(state).cpu().data.numpy().flatten()

  def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
    
    for it in range(iterations):
      
      # Step 4: We sample a batch of transitions (s, s’, a, r) from the memory
      batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
      state = torch.Tensor(batch_states).to(device)
      next_state = torch.Tensor(batch_next_states).to(device)
      action = torch.Tensor(batch_actions).to(device)
      reward = torch.Tensor(batch_rewards).to(device)
      done = torch.Tensor(batch_dones).to(device)
      
      # Step 5: From the next state s’, the Actor target plays the next action a’
      next_action = self.actor_target(next_state) # when only call the object by itself, the first method is used. = self.actor_target.forward(next_state)   
      
      # Step 6: We add Gaussian noise to this next action a’ and we clamp it in a range of values supported by the environment
      noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device) # normal_ : value from gaussian distribution of (mean, standard deviation)
      noise = noise.clamp(-noise_clip, noise_clip)
      next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
      
      # Step 7: The two Critic targets take each the couple (s’, a’) as input and return two Q-values Qt1(s’,a’) and Qt2(s’,a’) as outputs
      target_Q1, target_Q2 = self.critic_target(next_state, next_action)
      
      # Step 8: We keep the minimum of these two Q-values: min(Qt1, Qt2)
      target_Q = torch.min(target_Q1, target_Q2)
      
      # Step 9: We get the final target of the two Critic models, which is: Qt = r + γ * min(Qt1, Qt2), where γ is the discount factor
      target_Q = reward + ((1 - done) * discount * target_Q).detach() # detach : when you do back-propagate, detached function is not computed = can do efficient computation
      
      # Step 10: The two Critic models take each the couple (s, a) as input and return two Q-values Q1(s,a) and Q2(s,a) as outputs
      current_Q1, current_Q2 = self.critic(state, action)
      
      # Step 11: We compute the loss coming from the two Critic models: Critic Loss = MSE_Loss(Q1(s,a), Qt) + MSE_Loss(Q2(s,a), Qt)
      critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
      
      # Step 12: We backpropagate this Critic loss and update the parameters of the two Critic models with a SGD optimizer
      self.critic_optimizer.zero_grad() # all the gradients is initialized to zeros
      critic_loss.backward()
      self.critic_optimizer.step()
      
      # Step 13: Once every two iterations, we update our Actor model by performing gradient ascent on the output of the first Critic model
      if it % policy_freq == 0:
        actor_loss = -self.critic.Q1(state, self.actor(state)).mean() # DPG : deterministic policy gradient(positive gradient technique)
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        # Step 14: Still once every two iterations, we update the weights of the Actor target by polyak averaging
        # polyak averaging : that very small part is removed is replaced by very small part of the actor model weight
        # why double iteration? : get first the weight of the actor target that we want to update,
                                # second, the weight of the actor model in order to add component in the update
        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
        
        # Step 15: Still once every two iterations, we update the weights of the Critic target by polyak averaging
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
  
  # Making a save method to save a trained model
  def save(self, filename, directory):
    torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, filename))
    torch.save(self.critic.state_dict(), '%s/%s_critic.pth' % (directory, filename))
  
  # Making a load method to load a pre-trained model
  def load(self, filename, directory):
    self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, filename)))
    self.critic.load_state_dict(torch.load('%s/%s_critic.pth' % (directory, filename)))

# %% [markdown]
# ## We make a function that evaluates the policy by calculating its average reward over 10 episodes

# %%
def evaluate_policy(policy, eval_episodes=10):
  avg_reward = 0.
  for _ in range(eval_episodes):
    obs = env.reset()
    done = False
    while not done:
      action = policy.select_action(np.array(obs))
      obs, reward, done, _ = env.step(action)
      avg_reward += reward
  avg_reward /= eval_episodes
  print ("---------------------------------------")
  print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
  print ("---------------------------------------")
  return avg_reward

# %% [markdown]
# ## We set the parameters

# %%
env_name = "HalfCheetahBulletEnv-v0" # Name of a environment (set it to any Continous environment you want)
seed = 0 # Random seed number
start_timesteps = 1e4 # Number of iterations/timesteps before which the model randomly chooses an action, and after which it starts to use the policy network
eval_freq = 5e3 # How often the evaluation step is performed (after how many timesteps)
max_timesteps = 5e5 # Total number of iterations/timesteps
save_models = True # Boolean checker whether or not to save the pre-trained model
expl_noise = 0.1 # Exploration noise - STD value of exploration Gaussian noise
batch_size = 100 # Size of the batch
discount = 0.99 # Discount factor gamma, used in the calculation of the total discounted reward
tau = 0.005 # Target network update rate
policy_noise = 0.2 # STD of Gaussian noise added to the actions for the exploration purposes
noise_clip = 0.5 # Maximum value of the Gaussian noise added to the actions (policy)
policy_freq = 2 # Number of iterations to wait before the policy network (Actor model) is updated

# %% [markdown]
# ## We create a file name for the two saved models: the Actor and Critic models

# %%
file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")
# Out:
# ---------------------------------------
# Settings: TD3_HalfCheetahBulletEnv-v0_0
# ---------------------------------------

# %% [markdown]
# ## We create a folder inside which will be saved the trained models

# %%
if not os.path.exists("./results"):
  os.makedirs("./results")
if save_models and not os.path.exists("./pytorch_models"):
  os.makedirs("./pytorch_models")

# %% [markdown]
# ## We create the PyBullet environment

# %%
env = gym.make(env_name)

# %% [markdown]
# ## We set seeds and we get the necessary information on the states and actions in the chosen environment

# %%
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# %% [markdown]
# ## We create the policy network (the Actor model)

# %%
policy = TD3(state_dim, action_dim, max_action)

# %% [markdown]
# ## We create the Experience Replay memory

# %%
replay_buffer = ReplayBuffer()

# %% [markdown]
# ## We define a list where all the evaluation results over 10 episodes are stored

# %%
evaluations = [evaluate_policy(policy)]
# Out:
# ---------------------------------------
# Average Reward over the Evaluation Step: -1433.638437
# ---------------------------------------

# %% [markdown]
# ## We create a new folder directory in which the final results (videos of the agent) will be populated

# %%
def mkdir(base, name):
    path = os.path.join(base, name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path
work_dir = mkdir('exp', 'brs')
monitor_dir = mkdir(work_dir, 'monitor')
max_episode_steps = env._max_episode_steps
save_env_vid = False
if save_env_vid:
  env = wrappers.Monitor(env, monitor_dir, force = True)
  env.reset()

# %% [markdown]
# ## We initialize the variables

# %%
total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True
t0 = time.time()

# %% [markdown]
# ## Training

# %%
# We start the main loop over 500,000 timesteps
while total_timesteps < max_timesteps:
  
  # If the episode is done
  if done:

    # If we are not at the very beginning, we start the training process of the model
    if total_timesteps != 0:
      print("Total Timesteps: {} Episode Num: {} Reward: {}".format(total_timesteps, episode_num, episode_reward))
      policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)

    # We evaluate the episode and we save the policy
    if timesteps_since_eval >= eval_freq:
      timesteps_since_eval %= eval_freq
      evaluations.append(evaluate_policy(policy))
      policy.save(file_name, directory="./pytorch_models")
      np.save("./results/%s" % (file_name), evaluations)
    
    # When the training step is done, we reset the state of the environment
    obs = env.reset()
    
    # Set the Done to False
    done = False
    
    # Set rewards and episode timesteps to zero
    episode_reward = 0
    episode_timesteps = 0
    episode_num += 1
  
  # Before 10000 timesteps, we play random actions
  if total_timesteps < start_timesteps:
    action = env.action_space.sample()
  else: # After 10000 timesteps, we switch to the model
    action = policy.select_action(np.array(obs))
    # If the explore_noise parameter is not 0, we add noise to the action and we clip it
    if expl_noise != 0:
      action = (action + np.random.normal(0, expl_noise, size=env.action_space.shape[0])).clip(env.action_space.low, env.action_space.high)
  
  # The agent performs the action in the environment, then reaches the next state and receives the reward
  new_obs, reward, done, _ = env.step(action)
  
  # We check if the episode is done
  done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)
  
  # We increase the total reward
  episode_reward += reward
  
  # We store the new transition into the Experience Replay memory (ReplayBuffer)
  replay_buffer.add((obs, new_obs, action, reward, done_bool))

  # We update the state, the episode timestep, the total timesteps, and the timesteps since the evaluation of the policy
  obs = new_obs
  episode_timesteps += 1
  total_timesteps += 1
  timesteps_since_eval += 1

# We add the last policy evaluation to our list of evaluations and we save our model
evaluations.append(evaluate_policy(policy))
if save_models: policy.save("%s" % (file_name), directory="./pytorch_models")
np.save("./results/%s" % (file_name), evaluations)
# Out:
# Total Timesteps: 1000 Episode Num: 1 Reward: -1447.1443018309037
# Total Timesteps: 2000 Episode Num: 2 Reward: -1339.6786450772834
# Total Timesteps: 3000 Episode Num: 3 Reward: -1380.5554089352122
# Total Timesteps: 4000 Episode Num: 4 Reward: -1427.6309878497998
# Total Timesteps: 5000 Episode Num: 5 Reward: -1240.6285406497686
# ---------------------------------------
# Average Reward over the Evaluation Step: -1690.747842
# ---------------------------------------
# Total Timesteps: 6000 Episode Num: 6 Reward: -1315.0993351889645
# Total Timesteps: 7000 Episode Num: 7 Reward: -1174.7148191717674
# Total Timesteps: 8000 Episode Num: 8 Reward: -1390.1395606939882
# Total Timesteps: 9000 Episode Num: 9 Reward: -1352.1756126281218
# Total Timesteps: 10000 Episode Num: 10 Reward: -1192.5109116237056
# ---------------------------------------
# Average Reward over the Evaluation Step: -1889.480519
# ---------------------------------------
# Total Timesteps: 11000 Episode Num: 11 Reward: -1700.4411361463776
# Total Timesteps: 12000 Episode Num: 12 Reward: -1691.1742101471991
# Total Timesteps: 13000 Episode Num: 13 Reward: -1575.0245719501775
# Total Timesteps: 14000 Episode Num: 14 Reward: -1315.9623977832396
# Total Timesteps: 15000 Episode Num: 15 Reward: -1641.0988767401138
# ---------------------------------------
# Average Reward over the Evaluation Step: -1146.604595
# ---------------------------------------
# Total Timesteps: 16000 Episode Num: 16 Reward: 348.2385767696605
# Total Timesteps: 17000 Episode Num: 17 Reward: -1487.9626138535486
# Total Timesteps: 18000 Episode Num: 18 Reward: 520.1521533426417
# Total Timesteps: 19000 Episode Num: 19 Reward: 464.7593551858764
# Total Timesteps: 20000 Episode Num: 20 Reward: 413.67580969329464
# ---------------------------------------
# Average Reward over the Evaluation Step: -544.733122
# ---------------------------------------
# Total Timesteps: 21000 Episode Num: 21 Reward: -1599.8611201791107
# Total Timesteps: 22000 Episode Num: 22 Reward: -429.1803443402716
# Total Timesteps: 23000 Episode Num: 23 Reward: -1416.093052899648
# Total Timesteps: 24000 Episode Num: 24 Reward: -490.84551230781983
# Total Timesteps: 25000 Episode Num: 25 Reward: -1482.5930345653521
# ---------------------------------------
# Average Reward over the Evaluation Step: -751.659695
# ---------------------------------------
# Total Timesteps: 26000 Episode Num: 26 Reward: -515.8086395487954
# Total Timesteps: 27000 Episode Num: 27 Reward: 431.08172234258706
# Total Timesteps: 28000 Episode Num: 28 Reward: 348.8320158611633
# Total Timesteps: 29000 Episode Num: 29 Reward: 97.18558486722407
# Total Timesteps: 30000 Episode Num: 30 Reward: 460.0584638309611
# ---------------------------------------
# Average Reward over the Evaluation Step: 377.586807
# ---------------------------------------
# Total Timesteps: 31000 Episode Num: 31 Reward: 361.71183525102407
# Total Timesteps: 32000 Episode Num: 32 Reward: 198.75364375454345
# Total Timesteps: 33000 Episode Num: 33 Reward: -1154.9065929516003
# Total Timesteps: 34000 Episode Num: 34 Reward: -130.06137600835365
# Total Timesteps: 35000 Episode Num: 35 Reward: 404.19595035308504
# ---------------------------------------
# Average Reward over the Evaluation Step: -632.631464
# ---------------------------------------
# Total Timesteps: 36000 Episode Num: 36 Reward: -963.2903581533437
# Total Timesteps: 37000 Episode Num: 37 Reward: -5.34017842262523
# Total Timesteps: 38000 Episode Num: 38 Reward: 248.55301728687053
# Total Timesteps: 39000 Episode Num: 39 Reward: -425.33770015668773
# Total Timesteps: 40000 Episode Num: 40 Reward: 131.12678822825075
# ---------------------------------------
# Average Reward over the Evaluation Step: 420.179464
# ---------------------------------------
# Total Timesteps: 41000 Episode Num: 41 Reward: 146.1221415208786
# Total Timesteps: 42000 Episode Num: 42 Reward: -651.6667753086462
# Total Timesteps: 43000 Episode Num: 43 Reward: 203.796175845729
# Total Timesteps: 44000 Episode Num: 44 Reward: 576.655119719378
# Total Timesteps: 45000 Episode Num: 45 Reward: 489.3602857745855
# ---------------------------------------
# Average Reward over the Evaluation Step: 448.620694
# ---------------------------------------
# Total Timesteps: 46000 Episode Num: 46 Reward: 425.0137245648455
# Total Timesteps: 47000 Episode Num: 47 Reward: 563.6088880109291
# Total Timesteps: 48000 Episode Num: 48 Reward: 626.0009117519515
# Total Timesteps: 49000 Episode Num: 49 Reward: -177.38083818704925
# Total Timesteps: 50000 Episode Num: 50 Reward: 249.1811449197564
# ---------------------------------------
# Average Reward over the Evaluation Step: 391.369147
# ---------------------------------------
# Total Timesteps: 51000 Episode Num: 51 Reward: -586.5232826677079
# Total Timesteps: 52000 Episode Num: 52 Reward: 364.31446288004236
# Total Timesteps: 53000 Episode Num: 53 Reward: 589.9129171017785
# Total Timesteps: 54000 Episode Num: 54 Reward: 316.64209731068195
# Total Timesteps: 55000 Episode Num: 55 Reward: 561.5954995516148
# ---------------------------------------
# Average Reward over the Evaluation Step: 470.517299
# ---------------------------------------
# Total Timesteps: 56000 Episode Num: 56 Reward: 516.6619794047534
# Total Timesteps: 57000 Episode Num: 57 Reward: 540.583491891562
# Total Timesteps: 58000 Episode Num: 58 Reward: 672.6320022729254
# Total Timesteps: 59000 Episode Num: 59 Reward: 559.8214055946523
# Total Timesteps: 60000 Episode Num: 60 Reward: -875.0662355483481
# ---------------------------------------
# Average Reward over the Evaluation Step: 677.001263
# ---------------------------------------
# Total Timesteps: 61000 Episode Num: 61 Reward: 674.2773608979589
# Total Timesteps: 62000 Episode Num: 62 Reward: 654.9789246694263
# Total Timesteps: 63000 Episode Num: 63 Reward: 453.47612201181664
# Total Timesteps: 64000 Episode Num: 64 Reward: 585.8611837760102
# Total Timesteps: 65000 Episode Num: 65 Reward: 432.4659802141701
# ---------------------------------------
# Average Reward over the Evaluation Step: 487.882298
# ---------------------------------------
# Total Timesteps: 66000 Episode Num: 66 Reward: 433.6850620010631
# Total Timesteps: 67000 Episode Num: 67 Reward: 480.3646436742212
# Total Timesteps: 68000 Episode Num: 68 Reward: 425.1928877357105
# Total Timesteps: 69000 Episode Num: 69 Reward: 501.62331044124363
# Total Timesteps: 70000 Episode Num: 70 Reward: 484.73301053626926
# ---------------------------------------
# Average Reward over the Evaluation Step: 612.852788
# ---------------------------------------
# Total Timesteps: 71000 Episode Num: 71 Reward: 715.0524413267369
# Total Timesteps: 72000 Episode Num: 72 Reward: 476.4090912670018
# Total Timesteps: 73000 Episode Num: 73 Reward: 110.8832622475381
# Total Timesteps: 74000 Episode Num: 74 Reward: 531.9635098287372
# Total Timesteps: 75000 Episode Num: 75 Reward: 597.1655848544898
# ---------------------------------------
# Average Reward over the Evaluation Step: 236.213458
# ---------------------------------------
# Total Timesteps: 76000 Episode Num: 76 Reward: 427.05254954595716
# Total Timesteps: 77000 Episode Num: 77 Reward: 769.7634108206331
# Total Timesteps: 78000 Episode Num: 78 Reward: 477.3659242499881
# Total Timesteps: 79000 Episode Num: 79 Reward: 457.93670746448646
# Total Timesteps: 80000 Episode Num: 80 Reward: 532.1877368254912
# ---------------------------------------
# Average Reward over the Evaluation Step: 418.486376
# ---------------------------------------
# Total Timesteps: 81000 Episode Num: 81 Reward: 413.3583022065715
# Total Timesteps: 82000 Episode Num: 82 Reward: 448.20301500938314
# Total Timesteps: 83000 Episode Num: 83 Reward: 477.5112606942069
# Total Timesteps: 84000 Episode Num: 84 Reward: 501.1130852245804
# Total Timesteps: 85000 Episode Num: 85 Reward: -580.8341252268733
# ---------------------------------------
# Average Reward over the Evaluation Step: 592.198055
# ---------------------------------------
# Total Timesteps: 86000 Episode Num: 86 Reward: 562.9718981206154
# Total Timesteps: 87000 Episode Num: 87 Reward: 565.1740493636619
# Total Timesteps: 88000 Episode Num: 88 Reward: 666.1487319908365
# Total Timesteps: 89000 Episode Num: 89 Reward: 472.52679251962184
# Total Timesteps: 90000 Episode Num: 90 Reward: 372.3294077010404
# ---------------------------------------
# Average Reward over the Evaluation Step: 689.012116
# ---------------------------------------
# Total Timesteps: 91000 Episode Num: 91 Reward: 618.5796114489232
# Total Timesteps: 92000 Episode Num: 92 Reward: 792.2727852541905
# Total Timesteps: 93000 Episode Num: 93 Reward: 726.6568497339781
# Total Timesteps: 94000 Episode Num: 94 Reward: 684.6230507012925
# Total Timesteps: 95000 Episode Num: 95 Reward: 675.0294797457682
# ---------------------------------------
# Average Reward over the Evaluation Step: 593.235935
# ---------------------------------------
# Total Timesteps: 96000 Episode Num: 96 Reward: 576.5145856619082
# Total Timesteps: 97000 Episode Num: 97 Reward: 589.7974033979938
# Total Timesteps: 98000 Episode Num: 98 Reward: 736.3083325873679
# Total Timesteps: 99000 Episode Num: 99 Reward: 773.7809916540606
# Total Timesteps: 100000 Episode Num: 100 Reward: 790.6940549543853
# ---------------------------------------
# Average Reward over the Evaluation Step: 633.304602
# ---------------------------------------
# Total Timesteps: 101000 Episode Num: 101 Reward: 759.0037578884474
# Total Timesteps: 102000 Episode Num: 102 Reward: 677.5349505546117
# Total Timesteps: 103000 Episode Num: 103 Reward: 668.9840781020713
# Total Timesteps: 104000 Episode Num: 104 Reward: 653.7373960479399
# Total Timesteps: 105000 Episode Num: 105 Reward: 544.9119585182742
# ---------------------------------------
# Average Reward over the Evaluation Step: 700.910384
# ---------------------------------------
# Total Timesteps: 106000 Episode Num: 106 Reward: 743.0457402668949
# Total Timesteps: 107000 Episode Num: 107 Reward: 763.9396660832758
# Total Timesteps: 108000 Episode Num: 108 Reward: 771.1902623207327
# Total Timesteps: 109000 Episode Num: 109 Reward: 739.7757012789276
# Total Timesteps: 110000 Episode Num: 110 Reward: 753.3286834709523
# ---------------------------------------
# Average Reward over the Evaluation Step: 657.180806
# ---------------------------------------
# Total Timesteps: 111000 Episode Num: 111 Reward: 637.0703737236256
# Total Timesteps: 112000 Episode Num: 112 Reward: 765.4393833775335
# Total Timesteps: 113000 Episode Num: 113 Reward: 778.4856212377539
# Total Timesteps: 114000 Episode Num: 114 Reward: 630.3188839255475
# Total Timesteps: 115000 Episode Num: 115 Reward: 627.7209168642581
# ---------------------------------------
# Average Reward over the Evaluation Step: 112.937764
# ---------------------------------------
# Total Timesteps: 116000 Episode Num: 116 Reward: 382.0343882299193
# Total Timesteps: 117000 Episode Num: 117 Reward: 578.513947779214
# Total Timesteps: 118000 Episode Num: 118 Reward: -1524.946804560619
# Total Timesteps: 119000 Episode Num: 119 Reward: -1318.480814017936
# Total Timesteps: 120000 Episode Num: 120 Reward: -881.8734580263136
# ---------------------------------------
# Average Reward over the Evaluation Step: 794.026927
# ---------------------------------------
# Total Timesteps: 121000 Episode Num: 121 Reward: -615.1136681618021
# Total Timesteps: 122000 Episode Num: 122 Reward: -545.496972928551
# Total Timesteps: 123000 Episode Num: 123 Reward: -896.9841926320321
# Total Timesteps: 124000 Episode Num: 124 Reward: -170.33506239801574
# Total Timesteps: 125000 Episode Num: 125 Reward: 774.0220597957385
# ---------------------------------------
# Average Reward over the Evaluation Step: 680.637959
# ---------------------------------------
# Total Timesteps: 126000 Episode Num: 126 Reward: 490.472075664341
# Total Timesteps: 127000 Episode Num: 127 Reward: 382.76977754695656
# Total Timesteps: 128000 Episode Num: 128 Reward: 490.2154102351867
# Total Timesteps: 129000 Episode Num: 129 Reward: 734.3589385777648
# Total Timesteps: 130000 Episode Num: 130 Reward: 554.2133928076262
# ---------------------------------------
# Average Reward over the Evaluation Step: 465.492329
# ---------------------------------------
# Total Timesteps: 131000 Episode Num: 131 Reward: 681.5332273468106
# Total Timesteps: 132000 Episode Num: 132 Reward: -1658.1059212088553
# Total Timesteps: 133000 Episode Num: 133 Reward: -1481.9471393541378
# Total Timesteps: 134000 Episode Num: 134 Reward: -1462.1059227276924
# Total Timesteps: 135000 Episode Num: 135 Reward: -1621.1195314782608
# ---------------------------------------
# Average Reward over the Evaluation Step: -1564.275984
# ---------------------------------------
# Total Timesteps: 136000 Episode Num: 136 Reward: -1562.1894727778388
# Total Timesteps: 137000 Episode Num: 137 Reward: -1612.5040674457819
# Total Timesteps: 138000 Episode Num: 138 Reward: -1575.900689787348
# Total Timesteps: 139000 Episode Num: 139 Reward: -1693.4757832370676
# Total Timesteps: 140000 Episode Num: 140 Reward: -1839.987549617183
# ---------------------------------------
# Average Reward over the Evaluation Step: -1813.350411
# ---------------------------------------
# Total Timesteps: 141000 Episode Num: 141 Reward: -1705.2884639311899
# Total Timesteps: 142000 Episode Num: 142 Reward: -1665.122568834075
# Total Timesteps: 143000 Episode Num: 143 Reward: -1699.8590771942695
# Total Timesteps: 144000 Episode Num: 144 Reward: -1705.3836891708722
# Total Timesteps: 145000 Episode Num: 145 Reward: -1644.7434104206939
# ---------------------------------------
# Average Reward over the Evaluation Step: -2045.547804
# ---------------------------------------
# Total Timesteps: 146000 Episode Num: 146 Reward: -2016.2223175442268
# Total Timesteps: 147000 Episode Num: 147 Reward: -1700.181421515305
# Total Timesteps: 148000 Episode Num: 148 Reward: -1248.7777339390666
# Total Timesteps: 149000 Episode Num: 149 Reward: -983.5346706223622
# Total Timesteps: 150000 Episode Num: 150 Reward: -202.3224834874586
# ---------------------------------------
# Average Reward over the Evaluation Step: 378.133125
# ---------------------------------------
# Total Timesteps: 151000 Episode Num: 151 Reward: 360.54632646210825
# Total Timesteps: 152000 Episode Num: 152 Reward: -143.8170736462055
# Total Timesteps: 153000 Episode Num: 153 Reward: -1058.6720531988688
# Total Timesteps: 154000 Episode Num: 154 Reward: 560.9962513209775
# Total Timesteps: 155000 Episode Num: 155 Reward: -768.6601994779587
# ---------------------------------------
# Average Reward over the Evaluation Step: -74.381993
# ---------------------------------------
# Total Timesteps: 156000 Episode Num: 156 Reward: -1062.4816867257189
# Total Timesteps: 157000 Episode Num: 157 Reward: -1208.1685697870294
# Total Timesteps: 158000 Episode Num: 158 Reward: -855.7046750878642
# Total Timesteps: 159000 Episode Num: 159 Reward: 500.9569780745375
# Total Timesteps: 160000 Episode Num: 160 Reward: 69.29737589562211
# ---------------------------------------
# Average Reward over the Evaluation Step: 776.078240
# ---------------------------------------
# Total Timesteps: 161000 Episode Num: 161 Reward: 739.3923361379923
# Total Timesteps: 162000 Episode Num: 162 Reward: 674.6032814152645
# Total Timesteps: 163000 Episode Num: 163 Reward: -1191.0080503235556
# Total Timesteps: 164000 Episode Num: 164 Reward: -820.5997169936732
# Total Timesteps: 165000 Episode Num: 165 Reward: 280.0909332401779
# ---------------------------------------
# Average Reward over the Evaluation Step: 563.479759
# ---------------------------------------
# Total Timesteps: 166000 Episode Num: 166 Reward: 548.7519241279866
# Total Timesteps: 167000 Episode Num: 167 Reward: 37.38767191315148
# Total Timesteps: 168000 Episode Num: 168 Reward: 556.8277492762668
# Total Timesteps: 169000 Episode Num: 169 Reward: 688.6497600394541
# Total Timesteps: 170000 Episode Num: 170 Reward: 661.4269617231486
# ---------------------------------------
# Average Reward over the Evaluation Step: 783.631054
# ---------------------------------------
# Total Timesteps: 171000 Episode Num: 171 Reward: 695.4188371294484
# Total Timesteps: 172000 Episode Num: 172 Reward: 626.030748878188
# Total Timesteps: 173000 Episode Num: 173 Reward: 793.0203504403356
# Total Timesteps: 174000 Episode Num: 174 Reward: 774.8543849892014
# Total Timesteps: 175000 Episode Num: 175 Reward: 731.998113908613
# ---------------------------------------
# Average Reward over the Evaluation Step: 665.525040
# ---------------------------------------
# Total Timesteps: 176000 Episode Num: 176 Reward: 769.0329350466769
# Total Timesteps: 177000 Episode Num: 177 Reward: 731.3191734987215
# Total Timesteps: 178000 Episode Num: 178 Reward: 624.5497987560501
# Total Timesteps: 179000 Episode Num: 179 Reward: 701.0988475623494
# Total Timesteps: 180000 Episode Num: 180 Reward: 688.0422901447823
# ---------------------------------------
# Average Reward over the Evaluation Step: 687.495411
# ---------------------------------------
# Total Timesteps: 181000 Episode Num: 181 Reward: 695.4240696330987
# Total Timesteps: 182000 Episode Num: 182 Reward: 619.0025584521267
# Total Timesteps: 183000 Episode Num: 183 Reward: 609.6209835619419
# Total Timesteps: 184000 Episode Num: 184 Reward: 682.3918082010475
# Total Timesteps: 185000 Episode Num: 185 Reward: 704.9154885508207
# ---------------------------------------
# Average Reward over the Evaluation Step: 700.848222
# ---------------------------------------
# Total Timesteps: 186000 Episode Num: 186 Reward: 702.9314639906138
# Total Timesteps: 187000 Episode Num: 187 Reward: 689.9630287340061
# Total Timesteps: 188000 Episode Num: 188 Reward: 702.7619828155628
# Total Timesteps: 189000 Episode Num: 189 Reward: 600.4307674850394
# Total Timesteps: 190000 Episode Num: 190 Reward: 688.3014719482535
# ---------------------------------------
# Average Reward over the Evaluation Step: 732.423951
# ---------------------------------------
# Total Timesteps: 191000 Episode Num: 191 Reward: 698.3036041770838
# Total Timesteps: 192000 Episode Num: 192 Reward: 716.2412816074061
# Total Timesteps: 193000 Episode Num: 193 Reward: 660.015793936319
# Total Timesteps: 194000 Episode Num: 194 Reward: 619.9590782536673
# Total Timesteps: 195000 Episode Num: 195 Reward: -894.675252043274
# ---------------------------------------
# Average Reward over the Evaluation Step: 446.622562
# ---------------------------------------
# Total Timesteps: 196000 Episode Num: 196 Reward: 700.8734151326097
# Total Timesteps: 197000 Episode Num: 197 Reward: 704.2559042121919
# Total Timesteps: 198000 Episode Num: 198 Reward: 697.3220567069762
# Total Timesteps: 199000 Episode Num: 199 Reward: 612.8870964370067
# Total Timesteps: 200000 Episode Num: 200 Reward: 705.2020676114538
# ---------------------------------------
# Average Reward over the Evaluation Step: 680.799672
# ---------------------------------------
# Total Timesteps: 201000 Episode Num: 201 Reward: 701.2608876261312
# Total Timesteps: 202000 Episode Num: 202 Reward: 706.9351839275223
# Total Timesteps: 203000 Episode Num: 203 Reward: 717.5228858006508
# Total Timesteps: 204000 Episode Num: 204 Reward: 709.8726862854642
# Total Timesteps: 205000 Episode Num: 205 Reward: 702.0160893616329
# ---------------------------------------
# Average Reward over the Evaluation Step: 734.234292
# ---------------------------------------
# Total Timesteps: 206000 Episode Num: 206 Reward: 707.7400018585449
# Total Timesteps: 207000 Episode Num: 207 Reward: 723.3212517750055
# Total Timesteps: 208000 Episode Num: 208 Reward: 708.7503826648473
# Total Timesteps: 209000 Episode Num: 209 Reward: 777.8709609014957
# Total Timesteps: 210000 Episode Num: 210 Reward: 675.1338299474388
# ---------------------------------------
# Average Reward over the Evaluation Step: 792.017686
# ---------------------------------------
# Total Timesteps: 211000 Episode Num: 211 Reward: 767.8245030552283
# Total Timesteps: 212000 Episode Num: 212 Reward: 800.7976839653255
# Total Timesteps: 213000 Episode Num: 213 Reward: 861.9286705460835
# Total Timesteps: 214000 Episode Num: 214 Reward: 613.357791411535
# Total Timesteps: 215000 Episode Num: 215 Reward: 830.7299456137091
# ---------------------------------------
# Average Reward over the Evaluation Step: 383.030038
# ---------------------------------------
# Total Timesteps: 216000 Episode Num: 216 Reward: 102.15277108527441
# Total Timesteps: 217000 Episode Num: 217 Reward: 612.9077938084862
# Total Timesteps: 218000 Episode Num: 218 Reward: 613.2671329990097
# Total Timesteps: 219000 Episode Num: 219 Reward: 602.7924374275295
# Total Timesteps: 220000 Episode Num: 220 Reward: 607.3001701454717
# ---------------------------------------
# Average Reward over the Evaluation Step: 612.347723
# ---------------------------------------
# Total Timesteps: 221000 Episode Num: 221 Reward: 610.0231583946239
# Total Timesteps: 222000 Episode Num: 222 Reward: 611.9317402984447
# Total Timesteps: 223000 Episode Num: 223 Reward: 652.9215344573421
# Total Timesteps: 224000 Episode Num: 224 Reward: 608.3605819800235
# Total Timesteps: 225000 Episode Num: 225 Reward: 579.5327525277038
# ---------------------------------------
# Average Reward over the Evaluation Step: 613.671575
# ---------------------------------------
# Total Timesteps: 226000 Episode Num: 226 Reward: 604.1889493313868
# Total Timesteps: 227000 Episode Num: 227 Reward: 560.987614222155
# Total Timesteps: 228000 Episode Num: 228 Reward: 694.223666226069
# Total Timesteps: 229000 Episode Num: 229 Reward: 687.0592390654901
# Total Timesteps: 230000 Episode Num: 230 Reward: 688.4330789686287
# ---------------------------------------
# Average Reward over the Evaluation Step: 740.414083
# ---------------------------------------
# Total Timesteps: 231000 Episode Num: 231 Reward: 746.8369950754563
# Total Timesteps: 232000 Episode Num: 232 Reward: 788.0152598317782
# Total Timesteps: 233000 Episode Num: 233 Reward: 714.3053975124484
# Total Timesteps: 234000 Episode Num: 234 Reward: 676.0031746881828
# Total Timesteps: 235000 Episode Num: 235 Reward: 689.4825632483579
# ---------------------------------------
# Average Reward over the Evaluation Step: 750.147993
# ---------------------------------------
# Total Timesteps: 236000 Episode Num: 236 Reward: 681.7250665340733
# Total Timesteps: 237000 Episode Num: 237 Reward: 673.8324314118863
# Total Timesteps: 238000 Episode Num: 238 Reward: 861.6097267590055
# Total Timesteps: 239000 Episode Num: 239 Reward: 442.7165360099561
# Total Timesteps: 240000 Episode Num: 240 Reward: 840.4148735519842
# ---------------------------------------
# Average Reward over the Evaluation Step: 851.685898
# ---------------------------------------
# Total Timesteps: 241000 Episode Num: 241 Reward: 819.5365976474354
# Total Timesteps: 242000 Episode Num: 242 Reward: 238.56979532453093
# Total Timesteps: 243000 Episode Num: 243 Reward: 685.3699101868158
# Total Timesteps: 244000 Episode Num: 244 Reward: 764.127453284628
# Total Timesteps: 245000 Episode Num: 245 Reward: 797.8046160467418
# ---------------------------------------
# Average Reward over the Evaluation Step: 689.230625
# ---------------------------------------
# Total Timesteps: 246000 Episode Num: 246 Reward: 683.2975193873716
# Total Timesteps: 247000 Episode Num: 247 Reward: 859.9602722951009
# Total Timesteps: 248000 Episode Num: 248 Reward: 744.1175098003712
# Total Timesteps: 249000 Episode Num: 249 Reward: 793.2582071424374
# Total Timesteps: 250000 Episode Num: 250 Reward: 699.8300578324867
# ---------------------------------------
# Average Reward over the Evaluation Step: 722.202762
# ---------------------------------------
# Total Timesteps: 251000 Episode Num: 251 Reward: 848.1757878583859
# Total Timesteps: 252000 Episode Num: 252 Reward: 768.0617723150551
# Total Timesteps: 253000 Episode Num: 253 Reward: 703.2730183853286
# Total Timesteps: 254000 Episode Num: 254 Reward: 701.9446936996305
# Total Timesteps: 255000 Episode Num: 255 Reward: 871.8057522948042
# ---------------------------------------
# Average Reward over the Evaluation Step: 866.934834
# ---------------------------------------
# Total Timesteps: 256000 Episode Num: 256 Reward: 646.8181922511252
# Total Timesteps: 257000 Episode Num: 257 Reward: 874.0635339220781
# Total Timesteps: 258000 Episode Num: 258 Reward: 870.9390876179302
# Total Timesteps: 259000 Episode Num: 259 Reward: 840.9491208675348
# Total Timesteps: 260000 Episode Num: 260 Reward: 777.0198251048233
# ---------------------------------------
# Average Reward over the Evaluation Step: 890.149098
# ---------------------------------------
# Total Timesteps: 261000 Episode Num: 261 Reward: 877.1705194775153
# Total Timesteps: 262000 Episode Num: 262 Reward: 781.1233148232553
# Total Timesteps: 263000 Episode Num: 263 Reward: 871.0236921588671
# Total Timesteps: 264000 Episode Num: 264 Reward: 869.4012567184511
# Total Timesteps: 265000 Episode Num: 265 Reward: 666.6802205866185
# ---------------------------------------
# Average Reward over the Evaluation Step: 715.749632
# ---------------------------------------
# Total Timesteps: 266000 Episode Num: 266 Reward: 779.8810544246093
# Total Timesteps: 267000 Episode Num: 267 Reward: 544.9065623805417
# Total Timesteps: 268000 Episode Num: 268 Reward: 660.6533794259165
# Total Timesteps: 269000 Episode Num: 269 Reward: 775.4659711825651
# Total Timesteps: 270000 Episode Num: 270 Reward: 770.3467474848817
# ---------------------------------------
# Average Reward over the Evaluation Step: 658.963018
# ---------------------------------------
# Total Timesteps: 271000 Episode Num: 271 Reward: 597.0589832755861
# Total Timesteps: 272000 Episode Num: 272 Reward: 669.0263268980558
# Total Timesteps: 273000 Episode Num: 273 Reward: 850.5606568126533
# Total Timesteps: 274000 Episode Num: 274 Reward: 648.9216382287236
# Total Timesteps: 275000 Episode Num: 275 Reward: 668.7694877002181
# ---------------------------------------
# Average Reward over the Evaluation Step: 664.421906
# ---------------------------------------
# Total Timesteps: 276000 Episode Num: 276 Reward: 675.2766419309356
# Total Timesteps: 277000 Episode Num: 277 Reward: 679.1825239057896
# Total Timesteps: 278000 Episode Num: 278 Reward: 770.4922508428891
# Total Timesteps: 279000 Episode Num: 279 Reward: 783.1809116238097
# Total Timesteps: 280000 Episode Num: 280 Reward: 664.8515486191285
# ---------------------------------------
# Average Reward over the Evaluation Step: 845.563030
# ---------------------------------------
# Total Timesteps: 281000 Episode Num: 281 Reward: 881.1926560289164
# Total Timesteps: 282000 Episode Num: 282 Reward: 697.6305271170854
# Total Timesteps: 283000 Episode Num: 283 Reward: 721.2989607318364
# Total Timesteps: 284000 Episode Num: 284 Reward: 869.4208802237505
# Total Timesteps: 285000 Episode Num: 285 Reward: 746.8303451745162
# ---------------------------------------
# Average Reward over the Evaluation Step: 830.784929
# ---------------------------------------
# Total Timesteps: 286000 Episode Num: 286 Reward: 764.26509782025
# Total Timesteps: 287000 Episode Num: 287 Reward: 716.3890111427838
# Total Timesteps: 288000 Episode Num: 288 Reward: 692.256982302767
# Total Timesteps: 289000 Episode Num: 289 Reward: 690.1006485687615
# Total Timesteps: 290000 Episode Num: 290 Reward: 677.0832187210633
# ---------------------------------------
# Average Reward over the Evaluation Step: 799.802744
# ---------------------------------------
# Total Timesteps: 291000 Episode Num: 291 Reward: 804.0626332893307
# Total Timesteps: 292000 Episode Num: 292 Reward: 808.9211161067195
# Total Timesteps: 293000 Episode Num: 293 Reward: 699.1175981350543
# Total Timesteps: 294000 Episode Num: 294 Reward: 535.2161492717513
# Total Timesteps: 295000 Episode Num: 295 Reward: 691.0368729163191
# ---------------------------------------
# Average Reward over the Evaluation Step: 594.725644
# ---------------------------------------
# Total Timesteps: 296000 Episode Num: 296 Reward: 620.7268168919275
# Total Timesteps: 297000 Episode Num: 297 Reward: 657.7049836713279
# Total Timesteps: 298000 Episode Num: 298 Reward: 838.341166011524
# Total Timesteps: 299000 Episode Num: 299 Reward: 854.2550155888064
# Total Timesteps: 300000 Episode Num: 300 Reward: 687.4958427928041
# ---------------------------------------
# Average Reward over the Evaluation Step: 788.002024
# ---------------------------------------
# Total Timesteps: 301000 Episode Num: 301 Reward: 753.716720667212
# Total Timesteps: 302000 Episode Num: 302 Reward: 758.2059372295817
# Total Timesteps: 303000 Episode Num: 303 Reward: 826.7781916900701
# Total Timesteps: 304000 Episode Num: 304 Reward: 884.5689538946145
# Total Timesteps: 305000 Episode Num: 305 Reward: 847.7590716290139
# ---------------------------------------
# Average Reward over the Evaluation Step: 780.174915
# ---------------------------------------
# Total Timesteps: 306000 Episode Num: 306 Reward: 744.919343001093
# Total Timesteps: 307000 Episode Num: 307 Reward: 813.6768576492225
# Total Timesteps: 308000 Episode Num: 308 Reward: 926.6098593904984
# Total Timesteps: 309000 Episode Num: 309 Reward: 978.5568549101362
# Total Timesteps: 310000 Episode Num: 310 Reward: 807.8139113861779
# ---------------------------------------
# Average Reward over the Evaluation Step: 835.563349
# ---------------------------------------
# Total Timesteps: 311000 Episode Num: 311 Reward: 863.1495647234575
# Total Timesteps: 312000 Episode Num: 312 Reward: 809.9273596125843
# Total Timesteps: 313000 Episode Num: 313 Reward: 759.458680258955
# Total Timesteps: 314000 Episode Num: 314 Reward: 844.7669086432996
# Total Timesteps: 315000 Episode Num: 315 Reward: 755.8736498974472
# ---------------------------------------
# Average Reward over the Evaluation Step: 761.597699
# ---------------------------------------
# Total Timesteps: 316000 Episode Num: 316 Reward: 712.9614526565089
# Total Timesteps: 317000 Episode Num: 317 Reward: 880.5644705474288
# Total Timesteps: 318000 Episode Num: 318 Reward: 873.1138158590161
# Total Timesteps: 319000 Episode Num: 319 Reward: 808.3651472276847
# Total Timesteps: 320000 Episode Num: 320 Reward: 853.6106154063693
# ---------------------------------------
# Average Reward over the Evaluation Step: 776.092307
# ---------------------------------------
# Total Timesteps: 321000 Episode Num: 321 Reward: 796.5889057628694
# Total Timesteps: 322000 Episode Num: 322 Reward: 857.6746378326974
# Total Timesteps: 323000 Episode Num: 323 Reward: 884.3975637690573
# Total Timesteps: 324000 Episode Num: 324 Reward: 920.0578053669317
# Total Timesteps: 325000 Episode Num: 325 Reward: 860.4842689560653
# ---------------------------------------
# Average Reward over the Evaluation Step: 904.866596
# ---------------------------------------
# Total Timesteps: 326000 Episode Num: 326 Reward: 906.2597053108061
# Total Timesteps: 327000 Episode Num: 327 Reward: 954.6443774211184
# Total Timesteps: 328000 Episode Num: 328 Reward: 968.680087576378
# Total Timesteps: 329000 Episode Num: 329 Reward: 840.6111587015477
# Total Timesteps: 330000 Episode Num: 330 Reward: 913.975745376506
# ---------------------------------------
# Average Reward over the Evaluation Step: 898.591199
# ---------------------------------------
# Total Timesteps: 331000 Episode Num: 331 Reward: 913.6249340681431
# Total Timesteps: 332000 Episode Num: 332 Reward: 824.3343498403473
# Total Timesteps: 333000 Episode Num: 333 Reward: 917.8388639640912
# Total Timesteps: 334000 Episode Num: 334 Reward: 931.0237273134543
# Total Timesteps: 335000 Episode Num: 335 Reward: 870.0958235098673
# ---------------------------------------
# Average Reward over the Evaluation Step: 949.885859
# ---------------------------------------
# Total Timesteps: 336000 Episode Num: 336 Reward: 942.5400371915213
# Total Timesteps: 337000 Episode Num: 337 Reward: 915.8049468054567
# Total Timesteps: 338000 Episode Num: 338 Reward: 956.5432541189537
# Total Timesteps: 339000 Episode Num: 339 Reward: 1019.5297646803183
# Total Timesteps: 340000 Episode Num: 340 Reward: 965.4047538476486
# ---------------------------------------
# Average Reward over the Evaluation Step: 967.173134
# ---------------------------------------
# Total Timesteps: 341000 Episode Num: 341 Reward: 954.5099724354029
# Total Timesteps: 342000 Episode Num: 342 Reward: 1002.4880358161968
# Total Timesteps: 343000 Episode Num: 343 Reward: 739.0865407098349
# Total Timesteps: 344000 Episode Num: 344 Reward: 967.7700367864902
# Total Timesteps: 345000 Episode Num: 345 Reward: 948.7607861109458
# ---------------------------------------
# Average Reward over the Evaluation Step: 933.935910
# ---------------------------------------
# Total Timesteps: 346000 Episode Num: 346 Reward: 915.0125484700213
# Total Timesteps: 347000 Episode Num: 347 Reward: 961.5436903263899
# Total Timesteps: 348000 Episode Num: 348 Reward: 922.5667383226288
# Total Timesteps: 349000 Episode Num: 349 Reward: 1001.590161845948
# Total Timesteps: 350000 Episode Num: 350 Reward: 1005.4000287100788
# ---------------------------------------
# Average Reward over the Evaluation Step: 954.669701
# ---------------------------------------
# Total Timesteps: 351000 Episode Num: 351 Reward: 944.5971918264706
# Total Timesteps: 352000 Episode Num: 352 Reward: 1013.1863169386972
# Total Timesteps: 353000 Episode Num: 353 Reward: 1084.0224023546477
# Total Timesteps: 354000 Episode Num: 354 Reward: 1116.0395823905244
# Total Timesteps: 355000 Episode Num: 355 Reward: 990.7118941475558
# ---------------------------------------
# Average Reward over the Evaluation Step: 1088.109112
# ---------------------------------------
# Total Timesteps: 356000 Episode Num: 356 Reward: 1065.4178213712014
# Total Timesteps: 357000 Episode Num: 357 Reward: 1108.4606977257922
# Total Timesteps: 358000 Episode Num: 358 Reward: 1117.7997007819451
# Total Timesteps: 359000 Episode Num: 359 Reward: 1052.0394087733416
# Total Timesteps: 360000 Episode Num: 360 Reward: 1037.930464818099
# ---------------------------------------
# Average Reward over the Evaluation Step: 1193.619708
# ---------------------------------------
# Total Timesteps: 361000 Episode Num: 361 Reward: 1164.8504972939277
# Total Timesteps: 362000 Episode Num: 362 Reward: 1077.9413411896076
# Total Timesteps: 363000 Episode Num: 363 Reward: 1096.228696076131
# Total Timesteps: 364000 Episode Num: 364 Reward: 1097.6455711464591
# Total Timesteps: 365000 Episode Num: 365 Reward: 1140.1136345875327
# ---------------------------------------
# Average Reward over the Evaluation Step: 1058.330858
# ---------------------------------------
# Total Timesteps: 366000 Episode Num: 366 Reward: 1071.4332642660688
# Total Timesteps: 367000 Episode Num: 367 Reward: 1162.8773942243351
# Total Timesteps: 368000 Episode Num: 368 Reward: 1189.7362804643412
# Total Timesteps: 369000 Episode Num: 369 Reward: 1204.3876394570289
# Total Timesteps: 370000 Episode Num: 370 Reward: 1133.4877856843127
# ---------------------------------------
# Average Reward over the Evaluation Step: 1237.472641
# ---------------------------------------
# Total Timesteps: 371000 Episode Num: 371 Reward: 1184.9526685841363
# Total Timesteps: 372000 Episode Num: 372 Reward: 1201.5071532732936
# Total Timesteps: 373000 Episode Num: 373 Reward: 1194.9416313784563
# Total Timesteps: 374000 Episode Num: 374 Reward: 1297.452452582998
# Total Timesteps: 375000 Episode Num: 375 Reward: 1216.4980138428307
# ---------------------------------------
# Average Reward over the Evaluation Step: 1183.943200
# ---------------------------------------
# Total Timesteps: 376000 Episode Num: 376 Reward: 1176.3409097224783
# Total Timesteps: 377000 Episode Num: 377 Reward: 1182.4953790696109
# Total Timesteps: 378000 Episode Num: 378 Reward: 1158.3327835207128
# Total Timesteps: 379000 Episode Num: 379 Reward: 1268.0290573620891
# Total Timesteps: 380000 Episode Num: 380 Reward: 1201.0337509939498
# ---------------------------------------
# Average Reward over the Evaluation Step: 1204.940424
# ---------------------------------------
# Total Timesteps: 381000 Episode Num: 381 Reward: 1251.62492520951
# Total Timesteps: 382000 Episode Num: 382 Reward: 1154.5763363606295
# Total Timesteps: 383000 Episode Num: 383 Reward: 1165.8315789547826
# Total Timesteps: 384000 Episode Num: 384 Reward: 1101.8047614900495
# Total Timesteps: 385000 Episode Num: 385 Reward: 1170.5563187947694
# ---------------------------------------
# Average Reward over the Evaluation Step: 1236.402159
# ---------------------------------------
# Total Timesteps: 386000 Episode Num: 386 Reward: 1176.3581186845347
# Total Timesteps: 387000 Episode Num: 387 Reward: 1109.470935616189
# Total Timesteps: 388000 Episode Num: 388 Reward: 1137.6526624749997
# Total Timesteps: 389000 Episode Num: 389 Reward: 1157.0490051558802
# Total Timesteps: 390000 Episode Num: 390 Reward: 1247.9911171524552
# ---------------------------------------
# Average Reward over the Evaluation Step: 1244.122213
# ---------------------------------------
# Total Timesteps: 391000 Episode Num: 391 Reward: 1196.3969113400572
# Total Timesteps: 392000 Episode Num: 392 Reward: 1191.4186411386813
# Total Timesteps: 393000 Episode Num: 393 Reward: 1275.5080700913195
# Total Timesteps: 394000 Episode Num: 394 Reward: 1152.172115725057
# Total Timesteps: 395000 Episode Num: 395 Reward: 1250.2141748069487
# ---------------------------------------
# Average Reward over the Evaluation Step: 1262.929701
# ---------------------------------------
# Total Timesteps: 396000 Episode Num: 396 Reward: 1261.6234182694789
# Total Timesteps: 397000 Episode Num: 397 Reward: 1290.698466043313
# Total Timesteps: 398000 Episode Num: 398 Reward: 1281.0535858212966
# Total Timesteps: 399000 Episode Num: 399 Reward: 1296.9525473938668
# Total Timesteps: 400000 Episode Num: 400 Reward: 1183.1706856040748
# ---------------------------------------
# Average Reward over the Evaluation Step: 1356.067974
# ---------------------------------------
# Total Timesteps: 401000 Episode Num: 401 Reward: 1287.4411673923978
# Total Timesteps: 402000 Episode Num: 402 Reward: 1229.0419747925118
# Total Timesteps: 403000 Episode Num: 403 Reward: 1348.700323404929
# Total Timesteps: 404000 Episode Num: 404 Reward: 1329.1179459095445
# Total Timesteps: 405000 Episode Num: 405 Reward: 1266.4621254876267
# ---------------------------------------
# Average Reward over the Evaluation Step: 1290.667047
# ---------------------------------------
# Total Timesteps: 406000 Episode Num: 406 Reward: 1247.218101831758
# Total Timesteps: 407000 Episode Num: 407 Reward: 1222.539120889516
# Total Timesteps: 408000 Episode Num: 408 Reward: 1266.216534513458
# Total Timesteps: 409000 Episode Num: 409 Reward: 1226.2825052590508
# Total Timesteps: 410000 Episode Num: 410 Reward: 1221.0799261013788
# ---------------------------------------
# Average Reward over the Evaluation Step: 1229.451570
# ---------------------------------------
# Total Timesteps: 411000 Episode Num: 411 Reward: 1157.0585572334815
# Total Timesteps: 412000 Episode Num: 412 Reward: 1174.3962563794034
# Total Timesteps: 413000 Episode Num: 413 Reward: 1147.061293720221
# Total Timesteps: 414000 Episode Num: 414 Reward: 1139.2086230675618
# Total Timesteps: 415000 Episode Num: 415 Reward: 1282.7330356757498
# ---------------------------------------
# Average Reward over the Evaluation Step: 1182.026680
# ---------------------------------------
# Total Timesteps: 416000 Episode Num: 416 Reward: 1252.3846682044964
# Total Timesteps: 417000 Episode Num: 417 Reward: 1216.7278633812564
# Total Timesteps: 418000 Episode Num: 418 Reward: 1258.7048457450524
# Total Timesteps: 419000 Episode Num: 419 Reward: 1217.3291785389802
# Total Timesteps: 420000 Episode Num: 420 Reward: 1297.9746949762502
# ---------------------------------------
# Average Reward over the Evaluation Step: 1324.227418
# ---------------------------------------
# Total Timesteps: 421000 Episode Num: 421 Reward: 1274.7198652570523
# Total Timesteps: 422000 Episode Num: 422 Reward: 1250.6397569580022
# Total Timesteps: 423000 Episode Num: 423 Reward: 1250.4596509376283
# Total Timesteps: 424000 Episode Num: 424 Reward: 1253.186846196629
# Total Timesteps: 425000 Episode Num: 425 Reward: 1302.7478310845138
# ---------------------------------------
# Average Reward over the Evaluation Step: 1308.418904
# ---------------------------------------
# Total Timesteps: 426000 Episode Num: 426 Reward: 1323.2536199435783
# Total Timesteps: 427000 Episode Num: 427 Reward: 1240.0218779940492
# Total Timesteps: 428000 Episode Num: 428 Reward: 1252.6246549138993
# Total Timesteps: 429000 Episode Num: 429 Reward: 1305.6949722602737
# Total Timesteps: 430000 Episode Num: 430 Reward: 1345.8013606242264
# ---------------------------------------
# Average Reward over the Evaluation Step: 1261.469826
# ---------------------------------------
# Total Timesteps: 431000 Episode Num: 431 Reward: 1291.0343829362105
# Total Timesteps: 432000 Episode Num: 432 Reward: 1290.2871380553956
# Total Timesteps: 433000 Episode Num: 433 Reward: 1276.9891511197043
# Total Timesteps: 434000 Episode Num: 434 Reward: 1249.1286646983608
# Total Timesteps: 435000 Episode Num: 435 Reward: 1247.9273695473744
# ---------------------------------------
# Average Reward over the Evaluation Step: 1320.419979
# ---------------------------------------
# Total Timesteps: 436000 Episode Num: 436 Reward: 1279.6741919850765
# Total Timesteps: 437000 Episode Num: 437 Reward: 1311.211507179521
# Total Timesteps: 438000 Episode Num: 438 Reward: 1196.2328441782631
# Total Timesteps: 439000 Episode Num: 439 Reward: 1262.6127101371737
# Total Timesteps: 440000 Episode Num: 440 Reward: 1270.1422348099481
# ---------------------------------------
# Average Reward over the Evaluation Step: 1232.644003
# ---------------------------------------
# Total Timesteps: 441000 Episode Num: 441 Reward: 1144.1951018692826
# Total Timesteps: 442000 Episode Num: 442 Reward: 1320.0372734030227
# Total Timesteps: 443000 Episode Num: 443 Reward: 1378.568772338844
# Total Timesteps: 444000 Episode Num: 444 Reward: 1288.251465440956
# Total Timesteps: 445000 Episode Num: 445 Reward: 1291.373509868383
# ---------------------------------------
# Average Reward over the Evaluation Step: 1325.580638
# ---------------------------------------
# Total Timesteps: 446000 Episode Num: 446 Reward: 1297.3536643532614
# Total Timesteps: 447000 Episode Num: 447 Reward: 1347.5310541877536
# Total Timesteps: 448000 Episode Num: 448 Reward: 1234.8412985740513
# Total Timesteps: 449000 Episode Num: 449 Reward: 1192.879231296898
# Total Timesteps: 450000 Episode Num: 450 Reward: 1194.591898785946
# ---------------------------------------
# Average Reward over the Evaluation Step: 1238.916729
# ---------------------------------------
# Total Timesteps: 451000 Episode Num: 451 Reward: 1216.192391406849
# Total Timesteps: 452000 Episode Num: 452 Reward: 1220.109448347408
# Total Timesteps: 453000 Episode Num: 453 Reward: 1255.7084866317168
# Total Timesteps: 454000 Episode Num: 454 Reward: 1343.1477743485266
# Total Timesteps: 455000 Episode Num: 455 Reward: 1251.0581651796942
# ---------------------------------------
# Average Reward over the Evaluation Step: 1364.900792
# ---------------------------------------
# Total Timesteps: 456000 Episode Num: 456 Reward: 1368.4963211879601
# Total Timesteps: 457000 Episode Num: 457 Reward: 1325.9264550509126
# Total Timesteps: 458000 Episode Num: 458 Reward: 1321.9109340698892
# Total Timesteps: 459000 Episode Num: 459 Reward: 1276.1576627731965
# Total Timesteps: 460000 Episode Num: 460 Reward: 1274.0455555644462
# ---------------------------------------
# Average Reward over the Evaluation Step: 1297.773082
# ---------------------------------------
# Total Timesteps: 461000 Episode Num: 461 Reward: 1281.7593433095165
# Total Timesteps: 462000 Episode Num: 462 Reward: 1315.6616781748237
# Total Timesteps: 463000 Episode Num: 463 Reward: 1306.3556467957092
# Total Timesteps: 464000 Episode Num: 464 Reward: 1411.6763201117235
# Total Timesteps: 465000 Episode Num: 465 Reward: 1346.233155303423
# ---------------------------------------
# Average Reward over the Evaluation Step: 1284.588431
# ---------------------------------------
# Total Timesteps: 466000 Episode Num: 466 Reward: 1280.8592599969925
# Total Timesteps: 467000 Episode Num: 467 Reward: 1356.228357610733
# Total Timesteps: 468000 Episode Num: 468 Reward: 1318.8143529961703
# Total Timesteps: 469000 Episode Num: 469 Reward: 1358.7999487020163
# Total Timesteps: 470000 Episode Num: 470 Reward: 1429.6257838695526
# ---------------------------------------
# Average Reward over the Evaluation Step: 1382.395916
# ---------------------------------------
# Total Timesteps: 471000 Episode Num: 471 Reward: 1383.324788642689
# Total Timesteps: 472000 Episode Num: 472 Reward: 1345.5760631287635
# Total Timesteps: 473000 Episode Num: 473 Reward: 1345.2700533950679
# Total Timesteps: 474000 Episode Num: 474 Reward: 1279.944024602546
# Total Timesteps: 475000 Episode Num: 475 Reward: 1297.0127457437134
# ---------------------------------------
# Average Reward over the Evaluation Step: 1369.441220
# ---------------------------------------
# Total Timesteps: 476000 Episode Num: 476 Reward: 1309.160908639359
# Total Timesteps: 477000 Episode Num: 477 Reward: 1395.0544151043398
# Total Timesteps: 478000 Episode Num: 478 Reward: 1424.381717094318
# Total Timesteps: 479000 Episode Num: 479 Reward: 1388.2867250920006
# Total Timesteps: 480000 Episode Num: 480 Reward: 1282.1133759142756
# ---------------------------------------
# Average Reward over the Evaluation Step: 1442.239086
# ---------------------------------------
# Total Timesteps: 481000 Episode Num: 481 Reward: 1325.4052800161976
# Total Timesteps: 482000 Episode Num: 482 Reward: 1440.0187734646042
# Total Timesteps: 483000 Episode Num: 483 Reward: 1413.4200661731093
# Total Timesteps: 484000 Episode Num: 484 Reward: 1466.1579452860847
# Total Timesteps: 485000 Episode Num: 485 Reward: 1489.721007269205
# ---------------------------------------
# Average Reward over the Evaluation Step: 1474.402821
# ---------------------------------------
# Total Timesteps: 486000 Episode Num: 486 Reward: 1447.2945208319532
# Total Timesteps: 487000 Episode Num: 487 Reward: 1459.3561081926532
# Total Timesteps: 488000 Episode Num: 488 Reward: 1463.6140763253527
# Total Timesteps: 489000 Episode Num: 489 Reward: 1440.6756391602512
# Total Timesteps: 490000 Episode Num: 490 Reward: 1455.8858656388297
# ---------------------------------------
# Average Reward over the Evaluation Step: 1518.056732
# ---------------------------------------
# Total Timesteps: 491000 Episode Num: 491 Reward: 1493.136962995757
# Total Timesteps: 492000 Episode Num: 492 Reward: 1526.4767970196187
# Total Timesteps: 493000 Episode Num: 493 Reward: 1361.9940942135638
# Total Timesteps: 494000 Episode Num: 494 Reward: 1377.3231570038565
# Total Timesteps: 495000 Episode Num: 495 Reward: 1532.5860639499572
# ---------------------------------------
# Average Reward over the Evaluation Step: 1524.984704
# ---------------------------------------
# Total Timesteps: 496000 Episode Num: 496 Reward: 1515.129115620508
# Total Timesteps: 497000 Episode Num: 497 Reward: 1495.6652546550517
# Total Timesteps: 498000 Episode Num: 498 Reward: 1529.0883051217425
# Total Timesteps: 499000 Episode Num: 499 Reward: 1577.722708043084
# ---------------------------------------
# Average Reward over the Evaluation Step: 1466.612170
# ---------------------------------------

# %% [markdown]
# ## Inference

# %%
class Actor(nn.Module):
  
  def __init__(self, state_dim, action_dim, max_action):
    super(Actor, self).__init__()
    self.layer_1 = nn.Linear(state_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, action_dim)
    self.max_action = max_action

  def forward(self, x):
    x = F.relu(self.layer_1(x))
    x = F.relu(self.layer_2(x))
    x = self.max_action * torch.tanh(self.layer_3(x)) 
    return x

class Critic(nn.Module):
  
  def __init__(self, state_dim, action_dim):
    super(Critic, self).__init__()
    # Defining the first Critic neural network
    self.layer_1 = nn.Linear(state_dim + action_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, 1)
    # Defining the second Critic neural network
    self.layer_4 = nn.Linear(state_dim + action_dim, 400)
    self.layer_5 = nn.Linear(400, 300)
    self.layer_6 = nn.Linear(300, 1)

  def forward(self, x, u):
    xu = torch.cat([x, u], 1)
    # Forward-Propagation on the first Critic Neural Network
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    # Forward-Propagation on the second Critic Neural Network
    x2 = F.relu(self.layer_4(xu))
    x2 = F.relu(self.layer_5(x2))
    x2 = self.layer_6(x2)
    return x1, x2

  def Q1(self, x, u):
    xu = torch.cat([x, u], 1)
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    return x1

# Selecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Building the whole Training Process into a class

class TD3(object):
  
  def __init__(self, state_dim, action_dim, max_action):
    self.actor = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target.load_state_dict(self.actor.state_dict())
    self.actor_optimizer = torch.optim.Adam(self.actor.parameters())
    self.critic = Critic(state_dim, action_dim).to(device)
    self.critic_target = Critic(state_dim, action_dim).to(device)
    self.critic_target.load_state_dict(self.critic.state_dict())
    self.critic_optimizer = torch.optim.Adam(self.critic.parameters())
    self.max_action = max_action

  def select_action(self, state):
    state = torch.Tensor(state.reshape(1, -1)).to(device)
    return self.actor(state).cpu().data.numpy().flatten()

  def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
    
    for it in range(iterations):
      
      # Step 4: We sample a batch of transitions (s, s’, a, r) from the memory
      batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
      state = torch.Tensor(batch_states).to(device)
      next_state = torch.Tensor(batch_next_states).to(device)
      action = torch.Tensor(batch_actions).to(device)
      reward = torch.Tensor(batch_rewards).to(device)
      done = torch.Tensor(batch_dones).to(device)
      
      # Step 5: From the next state s’, the Actor target plays the next action a’
      next_action = self.actor_target(next_state)
      
      # Step 6: We add Gaussian noise to this next action a’ and we clamp it in a range of values supported by the environment
      noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
      noise = noise.clamp(-noise_clip, noise_clip)
      next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
      
      # Step 7: The two Critic targets take each the couple (s’, a’) as input and return two Q-values Qt1(s’,a’) and Qt2(s’,a’) as outputs
      target_Q1, target_Q2 = self.critic_target(next_state, next_action)
      
      # Step 8: We keep the minimum of these two Q-values: min(Qt1, Qt2)
      target_Q = torch.min(target_Q1, target_Q2)
      
      # Step 9: We get the final target of the two Critic models, which is: Qt = r + γ * min(Qt1, Qt2), where γ is the discount factor
      target_Q = reward + ((1 - done) * discount * target_Q).detach()
      
      # Step 10: The two Critic models take each the couple (s, a) as input and return two Q-values Q1(s,a) and Q2(s,a) as outputs
      current_Q1, current_Q2 = self.critic(state, action)
      
      # Step 11: We compute the loss coming from the two Critic models: Critic Loss = MSE_Loss(Q1(s,a), Qt) + MSE_Loss(Q2(s,a), Qt)
      critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
      
      # Step 12: We backpropagate this Critic loss and update the parameters of the two Critic models with a SGD optimizer
      self.critic_optimizer.zero_grad()
      critic_loss.backward()
      self.critic_optimizer.step()
      
      # Step 13: Once every two iterations, we update our Actor model by performing gradient ascent on the output of the first Critic model
      if it % policy_freq == 0:
        actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        # Step 14: Still once every two iterations, we update the weights of the Actor target by polyak averaging
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
        
        # Step 15: Still once every two iterations, we update the weights of the Critic target by polyak averaging
        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
  
  # Making a save method to save a trained model
  def save(self, filename, directory):
    torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, filename))
    torch.save(self.critic.state_dict(), '%s/%s_critic.pth' % (directory, filename))
  
  # Making a load method to load a pre-trained model
  def load(self, filename, directory):
    self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, filename)))
    self.critic.load_state_dict(torch.load('%s/%s_critic.pth' % (directory, filename)))

def evaluate_policy(policy, eval_episodes=10):
  avg_reward = 0.
  for _ in range(eval_episodes):
    obs = env.reset()
    done = False
    while not done:
      action = policy.select_action(np.array(obs))
      obs, reward, done, _ = env.step(action)
      avg_reward += reward
  avg_reward /= eval_episodes
  print ("---------------------------------------")
  print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
  print ("---------------------------------------")
  return avg_reward

env_name = "HalfCheetahBulletEnv-v0"
seed = 0

file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")

eval_episodes = 10
save_env_vid = True
env = gym.make(env_name)
max_episode_steps = env._max_episode_steps
if save_env_vid:
  env = wrappers.Monitor(env, monitor_dir, force = True)
  env.reset()
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
policy = TD3(state_dim, action_dim, max_action)
policy.load(file_name, './pytorch_models/')
_ = evaluate_policy(policy, eval_episodes=eval_episodes)
# Out:
# ---------------------------------------
# Settings: TD3_HalfCheetahBulletEnv-v0_0
# ---------------------------------------
# ---------------------------------------
# Average Reward over the Evaluation Step: 1481.073389
# ---------------------------------------
